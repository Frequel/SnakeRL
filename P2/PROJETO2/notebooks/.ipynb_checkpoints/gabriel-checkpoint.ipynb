# %%
from pathlib import Path
import sys

sys.path.append(str(Path('').absolute().parent))


from stable_baselines3 import DQN, A2C
from stable_baselines3.a2c import MlpPolicy
from stable_baselines3.common.env_util import make_vec_env

from gym_snake.envs.SnakeEnv import SnakeEnv

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

import random
random.seed(42)
# Out:
# pygame 2.0.1 (SDL 2.0.14, Python 3.8.5)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
def plot_metrics(metrics, filepath=None):
    formatted_dict = {'episodes': [],
                      'metrics': [],
                      'results': []}

    n = len(metrics['score'])
    for i in range(n):        
        score = metrics['score'][i]
        reward = metrics['reward'][i]

        formatted_dict['episodes'].append(i)
        formatted_dict['metrics'].append('score')
        formatted_dict['results'].append(score)

        formatted_dict['episodes'].append(i)
        formatted_dict['metrics'].append('reward')
        formatted_dict['results'].append(reward)

    df_metrics = pd.DataFrame(formatted_dict)
    sns.lineplot(data=df_metrics, x='episodes', y='results', hue='metrics')
    if filepath is None:
        plt.show()
    else:
        plt.savefig(filepath)
        
def evaluate(model):
    snake_env = SnakeEnv(440, 440, enable_render=False)
    env = make_vec_env(lambda: snake_env, n_envs=1)
    obs = env.reset()

    for _ in range(10000):
        action, _states = model.predict(obs)
        obs, rewards, dones, info = env.step(action)
        env.render()

    return snake_env.record, np.mean(np.array(snake_env.results['score']))

# %% [markdown]
# ### Testando: Gamma

# %%
results = {}
for i in range(50):
    # enable_render=True turns on the display
    snake_env = SnakeEnv(440, 440, enable_render=False)
    env = make_vec_env(lambda: snake_env, n_envs=1)

    gamma = random.uniform(0.95, 1)
    
    model = A2C(MlpPolicy, env, verbose=1, learning_rate=1e-3, seed=42, gamma=gamma)
    model.learn(total_timesteps=20000, log_interval=1000)

    # Print rewards and scores for each episode
    max_train_score = snake_env.record
    mean_train_score = np.mean(np.array(snake_env.results['score']))
    max_test_score, mean_test_score = evaluate(model)
    print("iteration ", i, ": gamma", gamma)
    results[gamma] = (snake_env.results, max_train_score, max_test_score, mean_train_score, mean_test_score)
    
for gamma, result in results.items():
    metrics, max_train_score, max_test_score, mean_train_score, mean_test_score = result
    
    print("gamma", gamma)
    plot_metrics(metrics)    
    print("Max Train Score", max_train_score, "Max Test Score", max_test_score)
    print("Mean Train Score", mean_train_score, "Mean Test Score", mean_test_score)
    print("-"*100)
# Out:
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 78.9     |
# |    ep_rew_mean        | -33.8    |
# | time/                 |          |
# |    fps                | 239      |
# |    iterations         | 1000     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.199   |
# |    explained_variance | -205     |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | 0.0733   |
# |    value_loss         | 23.7     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 93.2     |
# |    ep_rew_mean        | -18      |
# | time/                 |          |
# |    fps                | 230      |
# |    iterations         | 2000     |
# |    time_elapsed       | 43       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.469   |
# |    explained_variance | -4.41    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | -0.275   |
# |    value_loss         | 0.262    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 107      |
# |    ep_rew_mean        | 15.9     |
# | time/                 |          |
# |    fps                | 247      |
# |    iterations         | 3000     |
# |    time_elapsed       | 60       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.0801  |
# |    explained_variance | 0.276    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.0971   |
# |    value_loss         | 7.09     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 118      |
# |    ep_rew_mean        | 42.4     |
# | time/                 |          |
# |    fps                | 266      |
# |    iterations         | 4000     |
# |    time_elapsed       | 75       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.0221  |
# |    explained_variance | 0.324    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 3999     |
# |    policy_loss        | 0.0218   |
# |    value_loss         | 33.1     |
# ------------------------------------
# iteration  0 : gamma 0.968652579173184
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 81.3     |
# |    ep_rew_mean        | -32.1    |
# | time/                 |          |
# |    fps                | 231      |
# |    iterations         | 1000     |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.451   |
# |    explained_variance | -1.76    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | 4.19     |
# |    value_loss         | 125      |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 66.8      |
# |    ep_rew_mean        | -5.8      |
# | time/                 |           |
# |    fps                | 259       |
# |    iterations         | 2000      |
# |    time_elapsed       | 38        |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -0.00107  |
# |    explained_variance | -300      |
# |    learning_rate      | 0.001     |
# |    n_updates          | 1999      |
# |    policy_loss        | -7.93e-05 |
# |    value_loss         | 0.815     |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 86.7     |
# |    ep_rew_mean        | 14.3     |
# | time/                 |          |
# |    fps                | 271      |
# |    iterations         | 3000     |
# |    time_elapsed       | 55       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.0649  |
# |    explained_variance | 0.494    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.0197   |
# |    value_loss         | 1.27     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 114      |
# |    ep_rew_mean        | 31.2     |
# | time/                 |          |
# |    fps                | 281      |
# |    iterations         | 4000     |
# |    time_elapsed       | 71       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.0229  |
# |    explained_variance | -1.3     |
# |    learning_rate      | 0.001    |
# |    n_updates          | 3999     |
# |    policy_loss        | 0.00169  |
# |    value_loss         | 0.584    |
# ------------------------------------
# iteration  1 : gamma 0.9876222823273976
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 76.1     |
# |    ep_rew_mean        | -28.3    |
# | time/                 |          |
# |    fps                | 339      |
# |    iterations         | 1000     |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.724   |
# |    explained_variance | -151     |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | -0.147   |
# |    value_loss         | 0.0875   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 86.4     |
# |    ep_rew_mean        | 1.5      |
# | time/                 |          |
# |    fps                | 342      |
# |    iterations         | 2000     |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.0619  |
# |    explained_variance | -13.1    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | 0.0359   |
# |    value_loss         | 34       |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 111       |
# |    ep_rew_mean        | 34.8      |
# | time/                 |           |
# |    fps                | 344       |
# |    iterations         | 3000      |
# |    time_elapsed       | 43        |
# |    total_timesteps    | 15000     |
# | train/                |           |
# |    entropy_loss       | -0.00101  |
# |    explained_variance | -0.404    |
# |    learning_rate      | 0.001     |
# |    n_updates          | 2999      |
# |    policy_loss        | -0.000113 |
# |    value_loss         | 1.68      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 141      |
# |    ep_rew_mean        | 60       |
# | time/                 |          |
# |    fps                | 348      |
# |    iterations         | 4000     |
# |    time_elapsed       | 57       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.00066 |
# |    explained_variance | -223     |
# |    learning_rate      | 0.001    |
# |    n_updates          | 3999     |
# |    policy_loss        | 8.54e-05 |
# |    value_loss         | 37       |
# ------------------------------------
# iteration  2 : gamma 0.9707112544682519
# Using cpu device
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 76.9      |
# |    ep_rew_mean        | -33.1     |
# | time/                 |           |
# |    fps                | 241       |
# |    iterations         | 1000      |
# |    time_elapsed       | 20        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -0.599    |
# |    explained_variance | 0.372     |
# |    learning_rate      | 0.001     |
# |    n_updates          | 999       |
# |    policy_loss        | -0.000716 |
# |    value_loss         | 0.0142    |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 70.9     |
# |    ep_rew_mean        | -9.7     |
# | time/                 |          |
# |    fps                | 237      |
# |    iterations         | 2000     |
# |    time_elapsed       | 42       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.193   |
# |    explained_variance | 0.345    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | 2.4      |
# |    value_loss         | 54.3     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 91.3     |
# |    ep_rew_mean        | 9.9      |
# | time/                 |          |
# |    fps                | 237      |
# |    iterations         | 3000     |
# |    time_elapsed       | 63       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.0249  |
# |    explained_variance | -12.9    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.0318   |
# |    value_loss         | 74.4     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 111       |
# |    ep_rew_mean        | 22.7      |
# | time/                 |           |
# |    fps                | 237       |
# |    iterations         | 4000      |
# |    time_elapsed       | 84        |
# |    total_timesteps    | 20000     |
# | train/                |           |
# |    entropy_loss       | -0.000267 |
# |    explained_variance | nan       |
# |    learning_rate      | 0.001     |
# |    n_updates          | 3999      |
# |    policy_loss        | -2.19e-05 |
# |    value_loss         | 1.26      |
# -------------------------------------
# iteration  3 : gamma 0.9679556054918782
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 161      |
# |    ep_rew_mean        | -42.6    |
# | time/                 |          |
# |    fps                | 241      |
# |    iterations         | 1000     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.913   |
# |    explained_variance | -0.0159  |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | 0.0393   |
# |    value_loss         | 0.00222  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 99.7     |
# |    ep_rew_mean        | -22.6    |
# | time/                 |          |
# |    fps                | 285      |
# |    iterations         | 2000     |
# |    time_elapsed       | 35       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.00889 |
# |    explained_variance | -522     |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | 0.017    |
# |    value_loss         | 233      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 83.2     |
# |    ep_rew_mean        | 8.1      |
# | time/                 |          |
# |    fps                | 298      |
# |    iterations         | 3000     |
# |    time_elapsed       | 50       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.207   |
# |    explained_variance | -0.113   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.045    |
# |    value_loss         | 0.115    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 106      |
# |    ep_rew_mean        | 27.7     |
# | time/                 |          |
# |    fps                | 307      |
# |    iterations         | 4000     |
# |    time_elapsed       | 65       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.0654  |
# |    explained_variance | -0.444   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 3999     |
# |    policy_loss        | 0.0101   |
# |    value_loss         | 0.202    |
# ------------------------------------
# iteration  4 : gamma 0.9983405566784302
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 151      |
# |    ep_rew_mean        | -42.7    |
# | time/                 |          |
# |    fps                | 301      |
# |    iterations         | 1000     |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.294   |
# |    explained_variance | -0.169   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | 0.000102 |
# |    value_loss         | 3.54e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 115      |
# |    ep_rew_mean        | -20.1    |
# | time/                 |          |
# |    fps                | 277      |
# |    iterations         | 2000     |
# |    time_elapsed       | 36       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.162   |
# |    explained_variance | -524     |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | -3.93    |
# |    value_loss         | 1.47e+03 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 84        |
# |    ep_rew_mean        | 1.6       |
# | time/                 |           |
# |    fps                | 299       |
# |    iterations         | 3000      |
# |    time_elapsed       | 50        |
# |    total_timesteps    | 15000     |
# | train/                |           |
# |    entropy_loss       | -0.239    |
# |    explained_variance | -1.36e+03 |
# |    learning_rate      | 0.001     |
# |    n_updates          | 2999      |
# |    policy_loss        | 0.081     |
# |    value_loss         | 76.5      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 92.5     |
# |    ep_rew_mean        | 12.4     |
# | time/                 |          |
# |    fps                | 311      |
# |    iterations         | 4000     |
# |    time_elapsed       | 64       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.0227  |
# |    explained_variance | nan      |
# |    learning_rate      | 0.001    |
# |    n_updates          | 3999     |
# |    policy_loss        | -0.00056 |
# |    value_loss         | 0.0329   |
# ------------------------------------
# iteration  5 : gamma 0.9978618446956322
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 83       |
# |    ep_rew_mean        | -30.8    |
# | time/                 |          |
# |    fps                | 279      |
# |    iterations         | 1000     |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.264   |
# |    explained_variance | -158     |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | 0.509    |
# |    value_loss         | 47.6     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 66.9     |
# |    ep_rew_mean        | -10.2    |
# | time/                 |          |
# |    fps                | 278      |
# |    iterations         | 2000     |
# |    time_elapsed       | 35       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.0305  |
# |    explained_variance | -0.688   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | 9.8e-06  |
# |    value_loss         | 0.0115   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 93.3     |
# |    ep_rew_mean        | -3.5     |
# | time/                 |          |
# |    fps                | 299      |
# |    iterations         | 3000     |
# |    time_elapsed       | 50       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.518   |
# |    explained_variance | -72.2    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2999     |
# |    policy_loss        | -17.2    |
# |    value_loss         | 1.37e+03 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 104       |
# |    ep_rew_mean        | 3.8       |
# | time/                 |           |
# |    fps                | 309       |
# |    iterations         | 4000      |
# |    time_elapsed       | 64        |
# |    total_timesteps    | 20000     |
# | train/                |           |
# |    entropy_loss       | -0.0179   |
# |    explained_variance | -11.9     |
# |    learning_rate      | 0.001     |
# |    n_updates          | 3999      |
# |    policy_loss        | -0.000307 |
# |    value_loss         | 0.0139    |
# -------------------------------------
# iteration  6 : gamma 0.95662535022471
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 92.2     |
# |    ep_rew_mean        | -35.4    |
# | time/                 |          |
# |    fps                | 353      |
# |    iterations         | 1000     |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.668   |
# |    explained_variance | 0.294    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | 0.837    |
# |    value_loss         | 2.81     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 92.2     |
# |    ep_rew_mean        | -5       |
# | time/                 |          |
# |    fps                | 359      |
# |    iterations         | 2000     |
# |    time_elapsed       | 27       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.719   |
# |    explained_variance | -8.93    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | 2.93     |
# |    value_loss         | 84.7     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 97.5      |
# |    ep_rew_mean        | 23.7      |
# | time/                 |           |
# |    fps                | 320       |
# |    iterations         | 3000      |
# |    time_elapsed       | 46        |
# |    total_timesteps    | 15000     |
# | train/                |           |
# |    entropy_loss       | -0.000128 |
# |    explained_variance | nan       |
# |    learning_rate      | 0.001     |
# |    n_updates          | 2999      |
# |    policy_loss        | -1.2e-05  |
# |    value_loss         | 1.92      |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 118       |
# |    ep_rew_mean        | 39.1      |
# | time/                 |           |
# |    fps                | 306       |
# |    iterations         | 4000      |
# |    time_elapsed       | 65        |
# |    total_timesteps    | 20000     |
# | train/                |           |
# |    entropy_loss       | -6.57e-05 |
# |    explained_variance | nan       |
# |    learning_rate      | 0.001     |
# |    n_updates          | 3999      |
# |    policy_loss        | -5.46e-06 |
# |    value_loss         | 1.58      |
# -------------------------------------
# iteration  7 : gamma 0.9763227992700108
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 154      |
# |    ep_rew_mean        | -36.2    |
# | time/                 |          |
# |    fps                | 265      |
# |    iterations         | 1000     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.831   |
# |    explained_variance | 0.33     |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | 0.136    |
# |    value_loss         | 0.0313   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 84.1     |
# |    ep_rew_mean        | -22      |
# | time/                 |          |
# |    fps                | 266      |
# |    iterations         | 2000     |
# |    time_elapsed       | 37       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.222   |
# |    explained_variance | -6.84    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | -0.0142  |
# |    value_loss         | 0.0734   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 76.5     |
# |    ep_rew_mean        | -9.7     |
# | time/                 |          |
# |    fps                | 256      |
# |    iterations         | 3000     |
# |    time_elapsed       | 58       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.207   |
# |    explained_variance | -2.06    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2999     |
# |    policy_loss        | -0.0155  |
# |    value_loss         | 0.197    |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 104       |
# |    ep_rew_mean        | -0.4      |
# | time/                 |           |
# |    fps                | 245       |
# |    iterations         | 4000      |
# |    time_elapsed       | 81        |
# |    total_timesteps    | 20000     |
# | train/                |           |
# |    entropy_loss       | -0.0112   |
# |    explained_variance | 0.159     |
# |    learning_rate      | 0.001     |
# |    n_updates          | 3999      |
# |    policy_loss        | -0.000417 |
# |    value_loss         | 0.116     |
# -------------------------------------
# iteration  8 : gamma 0.9506332485779749
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 86.8     |
# |    ep_rew_mean        | -34.2    |
# | time/                 |          |
# |    fps                | 194      |
# |    iterations         | 1000     |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.204   |
# |    explained_variance | nan      |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | -0.00842 |
# |    value_loss         | 0.0456   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 81.8     |
# |    ep_rew_mean        | -5.1     |
# | time/                 |          |
# |    fps                | 237      |
# |    iterations         | 2000     |
# |    time_elapsed       | 42       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.0274  |
# |    explained_variance | nan      |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | -0.00431 |
# |    value_loss         | 1.54     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 99.2     |
# |    ep_rew_mean        | 23.8     |
# | time/                 |          |
# |    fps                | 240      |
# |    iterations         | 3000     |
# |    time_elapsed       | 62       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.115   |
# |    explained_variance | nan      |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2999     |
# |    policy_loss        | -0.016   |
# |    value_loss         | 0.686    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 120      |
# |    ep_rew_mean        | 39       |
# | time/                 |          |
# |    fps                | 259      |
# |    iterations         | 4000     |
# |    time_elapsed       | 77       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.01    |
# |    explained_variance | 0.437    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 3999     |
# |    policy_loss        | 0.00327  |
# |    value_loss         | 2.26     |
# ------------------------------------
# iteration  9 : gamma 0.9757687865104703
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 88.9     |
# |    ep_rew_mean        | -29.6    |
# | time/                 |          |
# |    fps                | 361      |
# |    iterations         | 1000     |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.4     |
# |    explained_variance | 0.342    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | 0.0783   |
# |    value_loss         | 0.0449   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 88.4     |
# |    ep_rew_mean        | -5.7     |
# | time/                 |          |
# |    fps                | 360      |
# |    iterations         | 2000     |
# |    time_elapsed       | 27       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.0582  |
# |    explained_variance | 0.734    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | -0.0035  |
# |    value_loss         | 0.212    |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 96.5      |
# |    ep_rew_mean        | 18        |
# | time/                 |           |
# |    fps                | 311       |
# |    iterations         | 3000      |
# |    time_elapsed       | 48        |
# |    total_timesteps    | 15000     |
# | train/                |           |
# |    entropy_loss       | -0.00202  |
# |    explained_variance | 0.498     |
# |    learning_rate      | 0.001     |
# |    n_updates          | 2999      |
# |    policy_loss        | -7.11e-05 |
# |    value_loss         | 1.47      |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 116       |
# |    ep_rew_mean        | 33.1      |
# | time/                 |           |
# |    fps                | 316       |
# |    iterations         | 4000      |
# |    time_elapsed       | 63        |
# |    total_timesteps    | 20000     |
# | train/                |           |
# |    entropy_loss       | -0.000283 |
# |    explained_variance | -4.96     |
# |    learning_rate      | 0.001     |
# |    n_updates          | 3999      |
# |    policy_loss        | -2.86e-05 |
# |    value_loss         | 1.78      |
# -------------------------------------
# iteration  10 : gamma 0.9720049710389925
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 145      |
# |    ep_rew_mean        | -37.1    |
# | time/                 |          |
# |    fps                | 326      |
# |    iterations         | 1000     |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.471   |
# |    explained_variance | 0.251    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | 0.0196   |
# |    value_loss         | 0.0128   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 94.3      |
# |    ep_rew_mean        | -12.1     |
# | time/                 |           |
# |    fps                | 297       |
# |    iterations         | 2000      |
# |    time_elapsed       | 33        |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -0.0417   |
# |    explained_variance | -7.03e+11 |
# |    learning_rate      | 0.001     |
# |    n_updates          | 1999      |
# |    policy_loss        | -0.00549  |
# |    value_loss         | 0.617     |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 82.9     |
# |    ep_rew_mean        | 11.5     |
# | time/                 |          |
# |    fps                | 284      |
# |    iterations         | 3000     |
# |    time_elapsed       | 52       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.00271 |
# |    explained_variance | -1.9     |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.000896 |
# |    value_loss         | 36       |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 108      |
# |    ep_rew_mean        | 29.5     |
# | time/                 |          |
# |    fps                | 297      |
# |    iterations         | 4000     |
# |    time_elapsed       | 67       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.212   |
# |    explained_variance | -4.05    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 3999     |
# |    policy_loss        | -0.151   |
# |    value_loss         | 0.23     |
# ------------------------------------
# iteration  11 : gamma 0.9525893637524327
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 83.1     |
# |    ep_rew_mean        | -29.7    |
# | time/                 |          |
# |    fps                | 265      |
# |    iterations         | 1000     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.427   |
# |    explained_variance | 0.479    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | -0.0238  |
# |    value_loss         | 0.0231   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 79.3     |
# |    ep_rew_mean        | -2.4     |
# | time/                 |          |
# |    fps                | 248      |
# |    iterations         | 2000     |
# |    time_elapsed       | 40       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.0361  |
# |    explained_variance | -0.369   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | -0.00579 |
# |    value_loss         | 1.01     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 98.6      |
# |    ep_rew_mean        | 24.4      |
# | time/                 |           |
# |    fps                | 252       |
# |    iterations         | 3000      |
# |    time_elapsed       | 59        |
# |    total_timesteps    | 15000     |
# | train/                |           |
# |    entropy_loss       | -0.000639 |
# |    explained_variance | 0.395     |
# |    learning_rate      | 0.001     |
# |    n_updates          | 2999      |
# |    policy_loss        | 3.09e-06  |
# |    value_loss         | 0.72      |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 116       |
# |    ep_rew_mean        | 41.3      |
# | time/                 |           |
# |    fps                | 247       |
# |    iterations         | 4000      |
# |    time_elapsed       | 80        |
# |    total_timesteps    | 20000     |
# | train/                |           |
# |    entropy_loss       | -0.000156 |
# |    explained_variance | -27.8     |
# |    learning_rate      | 0.001     |
# |    n_updates          | 3999      |
# |    policy_loss        | -9.29e-06 |
# |    value_loss         | 0.701     |
# -------------------------------------
# iteration  12 : gamma 0.9865465968743526
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 84.5     |
# |    ep_rew_mean        | -33.1    |
# | time/                 |          |
# |    fps                | 243      |
# |    iterations         | 1000     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.21    |
# |    explained_variance | -0.953   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | 0.0109   |
# |    value_loss         | 6.13     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 62.5     |
# |    ep_rew_mean        | -12.8    |
# | time/                 |          |
# |    fps                | 217      |
# |    iterations         | 2000     |
# |    time_elapsed       | 46       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.443   |
# |    explained_variance | 0.992    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | 0.103    |
# |    value_loss         | 0.281    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 86.8     |
# |    ep_rew_mean        | 8.5      |
# | time/                 |          |
# |    fps                | 210      |
# |    iterations         | 3000     |
# |    time_elapsed       | 71       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.145   |
# |    explained_variance | -0.322   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.0179   |
# |    value_loss         | 2.51     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 111       |
# |    ep_rew_mean        | 29.3      |
# | time/                 |           |
# |    fps                | 216       |
# |    iterations         | 4000      |
# |    time_elapsed       | 92        |
# |    total_timesteps    | 20000     |
# | train/                |           |
# |    entropy_loss       | -0.000176 |
# |    explained_variance | 0.223     |
# |    learning_rate      | 0.001     |
# |    n_updates          | 3999      |
# |    policy_loss        | 1.11e-05  |
# |    value_loss         | 15        |
# -------------------------------------
# iteration  13 : gamma 0.9838591688494536
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 79.5     |
# |    ep_rew_mean        | -33.9    |
# | time/                 |          |
# |    fps                | 200      |
# |    iterations         | 1000     |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.183   |
# |    explained_variance | -0.118   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | -0.00658 |
# |    value_loss         | 0.0878   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 80.5      |
# |    ep_rew_mean        | -7.6      |
# | time/                 |           |
# |    fps                | 217       |
# |    iterations         | 2000      |
# |    time_elapsed       | 45        |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -0.0049   |
# |    explained_variance | nan       |
# |    learning_rate      | 0.001     |
# |    n_updates          | 1999      |
# |    policy_loss        | -0.000577 |
# |    value_loss         | 1.42      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 96.5     |
# |    ep_rew_mean        | 21       |
# | time/                 |          |
# |    fps                | 222      |
# |    iterations         | 3000     |
# |    time_elapsed       | 67       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.0265  |
# |    explained_variance | 0.589    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.0057   |
# |    value_loss         | 7.55     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 116      |
# |    ep_rew_mean        | 41       |
# | time/                 |          |
# |    fps                | 227      |
# |    iterations         | 4000     |
# |    time_elapsed       | 87       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.00746 |
# |    explained_variance | 0.987    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 3999     |
# |    policy_loss        | 0.000389 |
# |    value_loss         | 0.308    |
# ------------------------------------
# iteration  14 : gamma 0.9685921883823383
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 83       |
# |    ep_rew_mean        | -34.7    |
# | time/                 |          |
# |    fps                | 209      |
# |    iterations         | 1000     |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.578   |
# |    explained_variance | -82      |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | 0.175    |
# |    value_loss         | 0.102    |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 78.9      |
# |    ep_rew_mean        | -6.3      |
# | time/                 |           |
# |    fps                | 235       |
# |    iterations         | 2000      |
# |    time_elapsed       | 42        |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -0.000867 |
# |    explained_variance | -34.9     |
# |    learning_rate      | 0.001     |
# |    n_updates          | 1999      |
# |    policy_loss        | -5.55e-05 |
# |    value_loss         | 0.441     |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 93.3      |
# |    ep_rew_mean        | 19.5      |
# | time/                 |           |
# |    fps                | 233       |
# |    iterations         | 3000      |
# |    time_elapsed       | 64        |
# |    total_timesteps    | 15000     |
# | train/                |           |
# |    entropy_loss       | -0.000897 |
# |    explained_variance | nan       |
# |    learning_rate      | 0.001     |
# |    n_updates          | 2999      |
# |    policy_loss        | 0.000552  |
# |    value_loss         | 45.5      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 116      |
# |    ep_rew_mean        | 38.4     |
# | time/                 |          |
# |    fps                | 238      |
# |    iterations         | 4000     |
# |    time_elapsed       | 83       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.0151  |
# |    explained_variance | 0.0203   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 3999     |
# |    policy_loss        | 6.47e-05 |
# |    value_loss         | 0.00156  |
# ------------------------------------
# iteration  15 : gamma 0.9892253608643671
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 99.2     |
# |    ep_rew_mean        | -36.6    |
# | time/                 |          |
# |    fps                | 251      |
# |    iterations         | 1000     |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.439   |
# |    explained_variance | -5.21    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | -0.0659  |
# |    value_loss         | 0.0321   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 85.8     |
# |    ep_rew_mean        | -18.1    |
# | time/                 |          |
# |    fps                | 212      |
# |    iterations         | 2000     |
# |    time_elapsed       | 47       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.0108  |
# |    explained_variance | 0.354    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | 0.000861 |
# |    value_loss         | 1.84     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 94.5      |
# |    ep_rew_mean        | 3.8       |
# | time/                 |           |
# |    fps                | 219       |
# |    iterations         | 3000      |
# |    time_elapsed       | 68        |
# |    total_timesteps    | 15000     |
# | train/                |           |
# |    entropy_loss       | -0.0029   |
# |    explained_variance | -6.2e+11  |
# |    learning_rate      | 0.001     |
# |    n_updates          | 2999      |
# |    policy_loss        | -6.68e-05 |
# |    value_loss         | 0.0527    |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 117      |
# |    ep_rew_mean        | 20.8     |
# | time/                 |          |
# |    fps                | 231      |
# |    iterations         | 4000     |
# |    time_elapsed       | 86       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.00406 |
# |    explained_variance | -0.313   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 3999     |
# |    policy_loss        | 0.000719 |
# |    value_loss         | 15.7     |
# ------------------------------------
# iteration  16 : gamma 0.956874576524848
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 87.6     |
# |    ep_rew_mean        | -33.3    |
# | time/                 |          |
# |    fps                | 255      |
# |    iterations         | 1000     |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.411   |
# |    explained_variance | -0.77    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | -17.3    |
# |    value_loss         | 2.65e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 79.9     |
# |    ep_rew_mean        | -5.8     |
# | time/                 |          |
# |    fps                | 248      |
# |    iterations         | 2000     |
# |    time_elapsed       | 40       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.239   |
# |    explained_variance | -164     |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | -13.2    |
# |    value_loss         | 1.7e+03  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 90.2     |
# |    ep_rew_mean        | 13.9     |
# | time/                 |          |
# |    fps                | 251      |
# |    iterations         | 3000     |
# |    time_elapsed       | 59       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.00554 |
# |    explained_variance | -5.1     |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.00697  |
# |    value_loss         | 98.9     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 121       |
# |    ep_rew_mean        | 38.2      |
# | time/                 |           |
# |    fps                | 265       |
# |    iterations         | 4000      |
# |    time_elapsed       | 75        |
# |    total_timesteps    | 20000     |
# | train/                |           |
# |    entropy_loss       | -0.00264  |
# |    explained_variance | nan       |
# |    learning_rate      | 0.001     |
# |    n_updates          | 3999      |
# |    policy_loss        | -0.000247 |
# |    value_loss         | 1.04      |
# -------------------------------------
# iteration  17 : gamma 0.9842657995897278
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 87.2     |
# |    ep_rew_mean        | -31.1    |
# | time/                 |          |
# |    fps                | 240      |
# |    iterations         | 1000     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.568   |
# |    explained_variance | 0.493    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | -0.272   |
# |    value_loss         | 0.775    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 87.4     |
# |    ep_rew_mean        | -13.6    |
# | time/                 |          |
# |    fps                | 237      |
# |    iterations         | 2000     |
# |    time_elapsed       | 42       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.388   |
# |    explained_variance | 0.451    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | 1.55     |
# |    value_loss         | 131      |
# ------------------------------------
# ------------------------------------
# ...
# |    iterations         | 1000     |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.183   |
# |    explained_variance | -0.118   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | -0.00658 |
# |    value_loss         | 0.0878   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 80.5      |
# |    ep_rew_mean        | -7.6      |
# | time/                 |           |
# |    fps                | 230       |
# |    iterations         | 2000      |
# |    time_elapsed       | 43        |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -0.0049   |
# |    explained_variance | nan       |
# |    learning_rate      | 0.001     |
# |    n_updates          | 1999      |
# |    policy_loss        | -0.000577 |
# |    value_loss         | 1.42      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 96.5     |
# |    ep_rew_mean        | 21       |
# | time/                 |          |
# |    fps                | 251      |
# |    iterations         | 3000     |
# |    time_elapsed       | 59       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.0265  |
# |    explained_variance | 0.589    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.0057   |
# |    value_loss         | 7.55     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 116      |
# |    ep_rew_mean        | 41       |
# | time/                 |          |
# |    fps                | 269      |
# |    iterations         | 4000     |
# |    time_elapsed       | 74       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.00746 |
# |    explained_variance | 0.987    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 3999     |
# |    policy_loss        | 0.000389 |
# |    value_loss         | 0.308    |
# ------------------------------------
# iteration  34 : gamma 0.9685921883823383
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 83       |
# |    ep_rew_mean        | -34.7    |
# | time/                 |          |
# |    fps                | 279      |
# |    iterations         | 1000     |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.578   |
# |    explained_variance | -82      |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | 0.175    |
# |    value_loss         | 0.102    |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 78.9      |
# |    ep_rew_mean        | -6.3      |
# | time/                 |           |
# |    fps                | 253       |
# |    iterations         | 2000      |
# |    time_elapsed       | 39        |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -0.000867 |
# |    explained_variance | -34.9     |
# |    learning_rate      | 0.001     |
# |    n_updates          | 1999      |
# |    policy_loss        | -5.55e-05 |
# |    value_loss         | 0.441     |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 93.3      |
# |    ep_rew_mean        | 19.5      |
# | time/                 |           |
# |    fps                | 272       |
# |    iterations         | 3000      |
# |    time_elapsed       | 55        |
# |    total_timesteps    | 15000     |
# | train/                |           |
# |    entropy_loss       | -0.000897 |
# |    explained_variance | nan       |
# |    learning_rate      | 0.001     |
# |    n_updates          | 2999      |
# |    policy_loss        | 0.000552  |
# |    value_loss         | 45.5      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 116      |
# |    ep_rew_mean        | 38.4     |
# | time/                 |          |
# |    fps                | 278      |
# |    iterations         | 4000     |
# |    time_elapsed       | 71       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.0151  |
# |    explained_variance | 0.0203   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 3999     |
# |    policy_loss        | 6.47e-05 |
# |    value_loss         | 0.00156  |
# ------------------------------------
# iteration  35 : gamma 0.9892253608643671
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 99.2     |
# |    ep_rew_mean        | -36.6    |
# | time/                 |          |
# |    fps                | 222      |
# |    iterations         | 1000     |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.439   |
# |    explained_variance | -5.21    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | -0.0659  |
# |    value_loss         | 0.0321   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 85.8     |
# |    ep_rew_mean        | -18.1    |
# | time/                 |          |
# |    fps                | 236      |
# |    iterations         | 2000     |
# |    time_elapsed       | 42       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.0108  |
# |    explained_variance | 0.354    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | 0.000861 |
# |    value_loss         | 1.84     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 94.5      |
# |    ep_rew_mean        | 3.8       |
# | time/                 |           |
# |    fps                | 265       |
# |    iterations         | 3000      |
# |    time_elapsed       | 56        |
# |    total_timesteps    | 15000     |
# | train/                |           |
# |    entropy_loss       | -0.0029   |
# |    explained_variance | -6.2e+11  |
# |    learning_rate      | 0.001     |
# |    n_updates          | 2999      |
# |    policy_loss        | -6.68e-05 |
# |    value_loss         | 0.0527    |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 117      |
# |    ep_rew_mean        | 20.8     |
# | time/                 |          |
# |    fps                | 280      |
# |    iterations         | 4000     |
# |    time_elapsed       | 71       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.00406 |
# |    explained_variance | -0.313   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 3999     |
# |    policy_loss        | 0.000719 |
# |    value_loss         | 15.7     |
# ------------------------------------
# iteration  36 : gamma 0.956874576524848
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 87.6     |
# |    ep_rew_mean        | -33.3    |
# | time/                 |          |
# |    fps                | 301      |
# |    iterations         | 1000     |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.411   |
# |    explained_variance | -0.77    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | -17.3    |
# |    value_loss         | 2.65e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 79.9     |
# |    ep_rew_mean        | -5.8     |
# | time/                 |          |
# |    fps                | 296      |
# |    iterations         | 2000     |
# |    time_elapsed       | 33       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.239   |
# |    explained_variance | -164     |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | -13.2    |
# |    value_loss         | 1.7e+03  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 90.2     |
# |    ep_rew_mean        | 13.9     |
# | time/                 |          |
# |    fps                | 307      |
# |    iterations         | 3000     |
# |    time_elapsed       | 48       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.00554 |
# |    explained_variance | -5.1     |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.00697  |
# |    value_loss         | 98.9     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 121       |
# |    ep_rew_mean        | 38.2      |
# | time/                 |           |
# |    fps                | 319       |
# |    iterations         | 4000      |
# |    time_elapsed       | 62        |
# |    total_timesteps    | 20000     |
# | train/                |           |
# |    entropy_loss       | -0.00264  |
# |    explained_variance | nan       |
# |    learning_rate      | 0.001     |
# |    n_updates          | 3999      |
# |    policy_loss        | -0.000247 |
# |    value_loss         | 1.04      |
# -------------------------------------
# iteration  37 : gamma 0.9842657995897278
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 87.2     |
# |    ep_rew_mean        | -31.1    |
# | time/                 |          |
# |    fps                | 235      |
# |    iterations         | 1000     |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.568   |
# |    explained_variance | 0.493    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | -0.272   |
# |    value_loss         | 0.775    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 87.4     |
# |    ep_rew_mean        | -13.6    |
# | time/                 |          |
# |    fps                | 239      |
# |    iterations         | 2000     |
# |    time_elapsed       | 41       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.388   |
# |    explained_variance | 0.451    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | 1.55     |
# |    value_loss         | 131      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 84.2     |
# |    ep_rew_mean        | 9.1      |
# | time/                 |          |
# |    fps                | 245      |
# |    iterations         | 3000     |
# |    time_elapsed       | 61       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.258   |
# |    explained_variance | 0.466    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.0127   |
# |    value_loss         | 0.364    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 111      |
# |    ep_rew_mean        | 21       |
# | time/                 |          |
# |    fps                | 262      |
# |    iterations         | 4000     |
# |    time_elapsed       | 76       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.154   |
# |    explained_variance | 0.574    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 3999     |
# |    policy_loss        | 0.0406   |
# |    value_loss         | 0.102    |
# ------------------------------------
# iteration  38 : gamma 0.9535506000847691
# Using cpu device
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 157       |
# |    ep_rew_mean        | -44.5     |
# | time/                 |           |
# |    fps                | 271       |
# |    iterations         | 1000      |
# |    time_elapsed       | 18        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -0.476    |
# |    explained_variance | -0.342    |
# |    learning_rate      | 0.001     |
# |    n_updates          | 999       |
# |    policy_loss        | -0.000187 |
# |    value_loss         | 9.85e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 107      |
# |    ep_rew_mean        | -28      |
# | time/                 |          |
# |    fps                | 271      |
# |    iterations         | 2000     |
# |    time_elapsed       | 36       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.352   |
# |    explained_variance | -0.00333 |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | -0.105   |
# |    value_loss         | 0.114    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 72.8     |
# |    ep_rew_mean        | -4.6     |
# | time/                 |          |
# |    fps                | 264      |
# |    iterations         | 3000     |
# |    time_elapsed       | 56       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.152   |
# |    explained_variance | nan      |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2999     |
# |    policy_loss        | -0.022   |
# |    value_loss         | 0.537    |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 98.6      |
# |    ep_rew_mean        | 11.4      |
# | time/                 |           |
# |    fps                | 255       |
# |    iterations         | 4000      |
# |    time_elapsed       | 78        |
# |    total_timesteps    | 20000     |
# | train/                |           |
# |    entropy_loss       | -0.00608  |
# |    explained_variance | -8.46e+11 |
# |    learning_rate      | 0.001     |
# |    n_updates          | 3999      |
# |    policy_loss        | -0.000332 |
# |    value_loss         | 0.289     |
# -------------------------------------
# iteration  39 : gamma 0.9554684712622143
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 130      |
# |    ep_rew_mean        | -42.2    |
# | time/                 |          |
# |    fps                | 287      |
# |    iterations         | 1000     |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.711   |
# |    explained_variance | -0.018   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | 0.00607  |
# |    value_loss         | 0.000635 |
# ------------------------------------

# %%
formatted_dict = {'gamma': [],
                  'metrics': [],
                  'results': []}

for gamma, result in results.items():
    _, max_train_score, max_test_score, mean_train_score, mean_test_score = result

    formatted_dict['gamma'].append(gamma)
    formatted_dict['metrics'].append('Max Train Score')
    formatted_dict['results'].append(max_train_score)

    formatted_dict['gamma'].append(gamma)
    formatted_dict['metrics'].append('Max Test Score')
    formatted_dict['results'].append(max_test_score)
    
    formatted_dict['gamma'].append(gamma)
    formatted_dict['metrics'].append('Mean Train Score')
    formatted_dict['results'].append(mean_train_score)

    formatted_dict['gamma'].append(gamma)
    formatted_dict['metrics'].append('Mean Test Score')
    formatted_dict['results'].append(mean_test_score)

df_metrics = pd.DataFrame(formatted_dict)
sns.lineplot(data=df_metrics, x='gamma', y='results', hue='metrics')

# %% [markdown]
# ### Testando: normalize_advantage
#
# Normalizar o ***advantage score*** piorou os resultados para todos os valores de gamma analizados.

# %%
results = {}
for _ in range(10):
    # enable_render=True turns on the display
    snake_env = SnakeEnv(440, 440, enable_render=False)
    env = make_vec_env(lambda: snake_env, n_envs=1)

    gamma = random.uniform(0.95, 1)
    
    model = A2C(MlpPolicy, env, verbose=1, learning_rate=1e-3, seed=42, gamma=gamma, normalize_advantage=True)
    model.learn(total_timesteps=20000, log_interval=1000)

    # Print rewards and scores for each episode
    max_train_score = snake_env.record
    mean_train_score = np.mean(np.array(snake_env.results['score']))
    max_test_score, mean_test_score = evaluate(model)
    
    results[gamma] = (snake_env.results, max_train_score, max_test_score, mean_train_score, mean_test_score)
    
for gamma, result in results.items():
    metrics, max_train_score, max_test_score, mean_train_score, mean_test_score = result
    
    print("Gamma", gamma)
    plot_metrics(metrics)    
    print("Max Train Score", max_train_score, "Max Test Score", max_test_score)
    print("Mean Train Score", mean_train_score, "Mean Test Score", mean_test_score)
    print("-"*100)
# Out:
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 119      |
# |    ep_rew_mean        | -41.5    |
# | time/                 |          |
# |    fps                | 244      |
# |    iterations         | 1000     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -1.02    |
# |    explained_variance | -0.00354 |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | -0.115   |
# |    value_loss         | 1e-06    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 117      |
# |    ep_rew_mean        | -35.5    |
# | time/                 |          |
# |    fps                | 253      |
# |    iterations         | 2000     |
# |    time_elapsed       | 39       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.618   |
# |    explained_variance | -5.68    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | 0.278    |
# |    value_loss         | 0.0317   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 96.1     |
# |    ep_rew_mean        | -19.9    |
# | time/                 |          |
# |    fps                | 243      |
# |    iterations         | 3000     |
# |    time_elapsed       | 61       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.203   |
# |    explained_variance | -0.573   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2999     |
# |    policy_loss        | -0.0444  |
# |    value_loss         | 0.0212   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 76.8     |
# |    ep_rew_mean        | -14.4    |
# | time/                 |          |
# |    fps                | 234      |
# |    iterations         | 4000     |
# |    time_elapsed       | 85       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.0441  |
# |    explained_variance | 0.425    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 3999     |
# |    policy_loss        | 0.00216  |
# |    value_loss         | 0.756    |
# ------------------------------------
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 104      |
# |    ep_rew_mean        | -41.7    |
# | time/                 |          |
# |    fps                | 280      |
# |    iterations         | 1000     |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.251   |
# |    explained_variance | -0.219   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | -0.132   |
# |    value_loss         | 5.4e-05  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 152      |
# |    ep_rew_mean        | -38.2    |
# | time/                 |          |
# |    fps                | 248      |
# |    iterations         | 2000     |
# |    time_elapsed       | 40       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.375   |
# |    explained_variance | 0.252    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | -0.0908  |
# |    value_loss         | 0.000293 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 141      |
# |    ep_rew_mean        | -40.8    |
# | time/                 |          |
# |    fps                | 244      |
# |    iterations         | 3000     |
# |    time_elapsed       | 61       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.28    |
# |    explained_variance | -0.206   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2999     |
# |    policy_loss        | -0.0818  |
# |    value_loss         | 0.000221 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 177      |
# |    ep_rew_mean        | -39.5    |
# | time/                 |          |
# |    fps                | 245      |
# |    iterations         | 4000     |
# |    time_elapsed       | 81       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.0037  |
# |    explained_variance | -10.9    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 3999     |
# |    policy_loss        | 4.46e-06 |
# |    value_loss         | 2.11e-12 |
# ------------------------------------
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 99.3     |
# |    ep_rew_mean        | -45.7    |
# | time/                 |          |
# |    fps                | 237      |
# |    iterations         | 1000     |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.485   |
# |    explained_variance | -0.158   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | -0.0251  |
# |    value_loss         | 0.00257  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 120       |
# |    ep_rew_mean        | -45.5     |
# | time/                 |           |
# |    fps                | 230       |
# |    iterations         | 2000      |
# |    time_elapsed       | 43        |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -0.00839  |
# |    explained_variance | -0.0771   |
# |    learning_rate      | 0.001     |
# |    n_updates          | 1999      |
# |    policy_loss        | -0.000405 |
# |    value_loss         | 5.67e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 154      |
# |    ep_rew_mean        | -43.3    |
# | time/                 |          |
# |    fps                | 244      |
# |    iterations         | 3000     |
# |    time_elapsed       | 61       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.443   |
# |    explained_variance | -0.536   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2999     |
# |    policy_loss        | -0.37    |
# |    value_loss         | 0.000501 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 166      |
# |    ep_rew_mean        | -36.2    |
# | time/                 |          |
# |    fps                | 242      |
# |    iterations         | 4000     |
# |    time_elapsed       | 82       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.411   |
# |    explained_variance | 0.155    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 3999     |
# |    policy_loss        | -0.64    |
# |    value_loss         | 0.000298 |
# ------------------------------------
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 141      |
# |    ep_rew_mean        | -42.3    |
# | time/                 |          |
# |    fps                | 223      |
# |    iterations         | 1000     |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.461   |
# |    explained_variance | 0.00321  |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | -0.0502  |
# |    value_loss         | 0.000936 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 154      |
# |    ep_rew_mean        | -40.9    |
# | time/                 |          |
# |    fps                | 238      |
# |    iterations         | 2000     |
# |    time_elapsed       | 41       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.535   |
# |    explained_variance | 0.134    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | -0.134   |
# |    value_loss         | 0.0481   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 171      |
# |    ep_rew_mean        | -38.5    |
# | time/                 |          |
# |    fps                | 235      |
# |    iterations         | 3000     |
# |    time_elapsed       | 63       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.0697  |
# |    explained_variance | -12.1    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.00474  |
# |    value_loss         | 0.000518 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 206      |
# |    ep_rew_mean        | -37      |
# | time/                 |          |
# |    fps                | 240      |
# |    iterations         | 4000     |
# |    time_elapsed       | 83       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.123   |
# |    explained_variance | -0.132   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 3999     |
# |    policy_loss        | 0.000948 |
# |    value_loss         | 0.00112  |
# ------------------------------------
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 137      |
# |    ep_rew_mean        | -42.8    |
# | time/                 |          |
# |    fps                | 230      |
# |    iterations         | 1000     |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.768   |
# |    explained_variance | -0.0229  |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | -0.362   |
# |    value_loss         | 0.00341  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 159      |
# |    ep_rew_mean        | -38.9    |
# | time/                 |          |
# |    fps                | 237      |
# |    iterations         | 2000     |
# |    time_elapsed       | 42       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.0379  |
# |    explained_variance | -10      |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | -0.00163 |
# |    value_loss         | 0.000152 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 170      |
# |    ep_rew_mean        | -35.9    |
# | time/                 |          |
# |    fps                | 241      |
# |    iterations         | 3000     |
# |    time_elapsed       | 62       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.419   |
# |    explained_variance | 0.123    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2999     |
# |    policy_loss        | -0.0018  |
# |    value_loss         | 0.0182   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 173      |
# |    ep_rew_mean        | -33.1    |
# | time/                 |          |
# |    fps                | 246      |
# |    iterations         | 4000     |
# |    time_elapsed       | 81       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.0166  |
# |    explained_variance | -1.31    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 3999     |
# |    policy_loss        | -0.00168 |
# |    value_loss         | 6.56e-15 |
# ------------------------------------
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 135      |
# |    ep_rew_mean        | -36.2    |
# | time/                 |          |
# |    fps                | 290      |
# |    iterations         | 1000     |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.688   |
# |    explained_variance | 0.318    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | -0.235   |
# |    value_loss         | 0.0017   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 77.6     |
# |    ep_rew_mean        | -44.9    |
# | time/                 |          |
# |    fps                | 248      |
# |    iterations         | 2000     |
# |    time_elapsed       | 40       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.469   |
# |    explained_variance | 0.414    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | -0.149   |
# |    value_loss         | 0.00407  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 96       |
# |    ep_rew_mean        | -48.6    |
# | time/                 |          |
# |    fps                | 242      |
# |    iterations         | 3000     |
# |    time_elapsed       | 61       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.151   |
# |    explained_variance | -0.0455  |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2999     |
# |    policy_loss        | -0.022   |
# |    value_loss         | 4.66e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 124      |
# |    ep_rew_mean        | -48.3    |
# | time/                 |          |
# |    fps                | 249      |
# |    iterations         | 4000     |
# |    time_elapsed       | 80       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.0142  |
# |    explained_variance | -3.29    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 3999     |
# |    policy_loss        | 0.000463 |
# |    value_loss         | 3.98e-06 |
# ------------------------------------
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 154      |
# |    ep_rew_mean        | -42.6    |
# | time/                 |          |
# |    fps                | 241      |
# |    iterations         | 1000     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.701   |
# |    explained_variance | 0.0592   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | -0.165   |
# |    value_loss         | 0.00144  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 147      |
# |    ep_rew_mean        | -41.5    |
# | time/                 |          |
# |    fps                | 225      |
# |    iterations         | 2000     |
# |    time_elapsed       | 44       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.0767  |
# |    explained_variance | -7.85    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | 0.00607  |
# |    value_loss         | 1.05e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 85.2     |
# |    ep_rew_mean        | -47.3    |
# | time/                 |          |
# |    fps                | 226      |
# |    iterations         | 3000     |
# |    time_elapsed       | 66       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.652   |
# |    explained_variance | -0.329   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2999     |
# |    policy_loss        | -0.297   |
# |    value_loss         | 0.00135  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 86.3     |
# |    ep_rew_mean        | -48.9    |
# | time/                 |          |
# |    fps                | 229      |
# |    iterations         | 4000     |
# |    time_elapsed       | 87       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.0128  |
# |    explained_variance | -9.2     |
# |    learning_rate      | 0.001    |
# |    n_updates          | 3999     |
# |    policy_loss        | 5.71e-06 |
# |    value_loss         | 1.47e-09 |
# ------------------------------------
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 97.1     |
# |    ep_rew_mean        | -44.9    |
# | time/                 |          |
# |    fps                | 221      |
# |    iterations         | 1000     |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.623   |
# |    explained_variance | -0.147   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | -0.378   |
# |    value_loss         | 0.000181 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 119      |
# |    ep_rew_mean        | -39.9    |
# | time/                 |          |
# |    fps                | 228      |
# |    iterations         | 2000     |
# |    time_elapsed       | 43       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.405   |
# |    explained_variance | 0.0235   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | -0.11    |
# |    value_loss         | 0.000463 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 113      |
# |    ep_rew_mean        | -24.3    |
# | time/                 |          |
# |    fps                | 235      |
# |    iterations         | 3000     |
# |    time_elapsed       | 63       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.643   |
# |    explained_variance | -0.00571 |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2999     |
# |    policy_loss        | -0.377   |
# |    value_loss         | 0.326    |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 84.7      |
# |    ep_rew_mean        | -6.8      |
# | time/                 |           |
# |    fps                | 256       |
# |    iterations         | 4000      |
# |    time_elapsed       | 78        |
# |    total_timesteps    | 20000     |
# | train/                |           |
# |    entropy_loss       | -0.00375  |
# |    explained_variance | nan       |
# |    learning_rate      | 0.001     |
# |    n_updates          | 3999      |
# |    policy_loss        | -1.16e-11 |
# |    value_loss         | 0.237     |
# -------------------------------------
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 51.4     |
# |    ep_rew_mean        | -45.7    |
# | time/                 |          |
# |    fps                | 271      |
# |    iterations         | 1000     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.844   |
# |    explained_variance | 0.0585   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | -0.0516  |
# |    value_loss         | 0.0406   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 53       |
# |    ep_rew_mean        | -38.9    |
# | time/                 |          |
# |    fps                | 237      |
# |    iterations         | 2000     |
# |    time_elapsed       | 42       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.657   |
# |    explained_variance | 0.008    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | 0.133    |
# |    value_loss         | 0.187    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 80.4     |
# |    ep_rew_mean        | -26.6    |
# | time/                 |          |
# |    fps                | 238      |
# |    iterations         | 3000     |
# |    time_elapsed       | 62       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.0255  |
# |    explained_variance | nan      |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2999     |
# |    policy_loss        | -1.7e-10 |
# |    value_loss         | 0.00535  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 83.8     |
# |    ep_rew_mean        | -19.2    |
# | time/                 |          |
# |    fps                | 246      |
# |    iterations         | 4000     |
# |    time_elapsed       | 81       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.0293  |
# |    explained_variance | -0.308   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 3999     |
# |    policy_loss        | 0.00192  |
# |    value_loss         | 0.0212   |
# ------------------------------------
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 172      |
# |    ep_rew_mean        | -35.9    |
# | time/                 |          |
# |    fps                | 273      |
# |    iterations         | 1000     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.712   |
# |    explained_variance | -0.344   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | -0.0731  |
# |    value_loss         | 0.000274 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 129      |
# |    ep_rew_mean        | -30.3    |
# | time/                 |          |
# |    fps                | 240      |
# |    iterations         | 2000     |
# |    time_elapsed       | 41       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.586   |
# |    explained_variance | -0.462   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | -0.184   |
# |    value_loss         | 0.000521 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 101      |
# |    ep_rew_mean        | -17.3    |
# | time/                 |          |
# |    fps                | 236      |
# |    iterations         | 3000     |
# |    time_elapsed       | 63       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.618   |
# |    explained_variance | -0.0475  |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.185    |
# |    value_loss         | 0.0866   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 106      |
# |    ep_rew_mean        | -1       |
# | time/                 |          |
# |    fps                | 237      |
# |    iterations         | 4000     |
# |    time_elapsed       | 84       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.0162  |
# |    explained_variance | -97.1    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 3999     |
# |    policy_loss        | -0.00142 |
# |    value_loss         | 61.2     |
# ------------------------------------
# Gamma 0.9558658099721666
# Max Train Score 10 Max Test Score 11
# Mean Train Score 1.5313159062381123 Mean Test Score 2.4016239550087564
# ----------------------------------------------------------------------------------------------------
# Gamma 0.9787879580368415
# Max Train Score 3 Max Test Score 0
# Mean Train Score 0.4207030777645884 Mean Test Score 0.0
# ----------------------------------------------------------------------------------------------------
# Gamma 0.9799472292230115
# Max Train Score 4 Max Test Score 5
# Mean Train Score 0.5743579519801391 Mean Test Score 1.5437310619002158
# ----------------------------------------------------------------------------------------------------
# Gamma 0.9854392641917085
# Max Train Score 3 Max Test Score 2
# Mean Train Score 0.7300714261274825 Mean Test Score 0.8559496712900571
# ----------------------------------------------------------------------------------------------------
# Gamma 0.9856474486409561
# Max Train Score 3 Max Test Score 4
# Mean Train Score 0.8129076985798346 Mean Test Score 1.438064314791575
# ----------------------------------------------------------------------------------------------------
# Gamma 0.9667923768310657
# Max Train Score 3 Max Test Score 2
# Mean Train Score 0.26159707373697694 Mean Test Score 0.47426771442392535
# ----------------------------------------------------------------------------------------------------
# Gamma 0.9860360909680097
# Max Train Score 3 Max Test Score 0
# Mean Train Score 0.22331498570850422 Mean Test Score 0.0
# ----------------------------------------------------------------------------------------------------
# Gamma 0.9697815950530332
# Max Train Score 17 Max Test Score 14
# Mean Train Score 1.4815552229272635 Mean Test Score 2.3807075747839375
# ----------------------------------------------------------------------------------------------------
# Gamma 0.9945665841176945
# Max Train Score 9 Max Test Score 11
# Mean Train Score 0.9708306040428534 Mean Test Score 2.350621533114969
# ----------------------------------------------------------------------------------------------------
# Gamma 0.9982205014326955
# Max Train Score 13 Max Test Score 18
# Mean Train Score 1.9621458424284015 Mean Test Score 3.745517725786342
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Testando: ent_coef

# %%
results = {}
for i in range(10):
    # enable_render=True turns on the display
    snake_env = SnakeEnv(440, 440, enable_render=False)
    env = make_vec_env(lambda: snake_env, n_envs=1)

    entropy = random.uniform(0, 0.1)
    
    model = A2C(MlpPolicy, env, verbose=1, learning_rate=1e-3, seed=42, gamma=0.98, ent_coef=entropy)
    model.learn(total_timesteps=20000, log_interval=1000)

    # Print rewards and scores for each episode
    max_train_score = snake_env.record
    mean_train_score = np.mean(np.array(snake_env.results['score']))
    max_test_score, mean_test_score = evaluate(model)
    print("iteration ", i, ": entropy", entropy)
    results[entropy] = (snake_env.results, max_train_score, max_test_score, mean_train_score, mean_test_score)
    
for entropy, result in results.items():
    metrics, max_train_score, max_test_score, mean_train_score, mean_test_score = result
    
    print("entropy", entropy)
    plot_metrics(metrics)    
    print("Max Train Score", max_train_score, "Max Test Score", max_test_score)
    print("Mean Train Score", mean_train_score, "Mean Test Score", mean_test_score)
    print("-"*100)
# Out:
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 99.3     |
# |    ep_rew_mean        | -40.8    |
# | time/                 |          |
# |    fps                | 215      |
# |    iterations         | 1000     |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.763   |
# |    explained_variance | 0.214    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | 0.0432   |
# |    value_loss         | 0.00782  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 77.7     |
# |    ep_rew_mean        | -15.5    |
# | time/                 |          |
# |    fps                | 219      |
# |    iterations         | 2000     |
# |    time_elapsed       | 45       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.129   |
# |    explained_variance | 0.295    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | 0.0476   |
# |    value_loss         | 7.71     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 83       |
# |    ep_rew_mean        | 9.6      |
# | time/                 |          |
# |    fps                | 226      |
# |    iterations         | 3000     |
# |    time_elapsed       | 66       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.0096  |
# |    explained_variance | nan      |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.000682 |
# |    value_loss         | 0.614    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 108      |
# |    ep_rew_mean        | 26.6     |
# | time/                 |          |
# |    fps                | 226      |
# |    iterations         | 4000     |
# |    time_elapsed       | 88       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.131   |
# |    explained_variance | 0.33     |
# |    learning_rate      | 0.001    |
# |    n_updates          | 3999     |
# |    policy_loss        | -0.0156  |
# |    value_loss         | 3.25     |
# ------------------------------------
# iteration  0 : entropy 0.027588144086158686
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 87.3     |
# |    ep_rew_mean        | -42.8    |
# | time/                 |          |
# |    fps                | 240      |
# |    iterations         | 1000     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -1.05    |
# |    explained_variance | -0.0775  |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | -0.0203  |
# |    value_loss         | 0.000705 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 93.4     |
# |    ep_rew_mean        | -33.2    |
# | time/                 |          |
# |    fps                | 238      |
# |    iterations         | 2000     |
# |    time_elapsed       | 41       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -1.05    |
# |    explained_variance | -0.105   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | -0.0278  |
# |    value_loss         | 0.00295  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 79.4     |
# |    ep_rew_mean        | -5.1     |
# | time/                 |          |
# |    fps                | 241      |
# |    iterations         | 3000     |
# |    time_elapsed       | 61       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.29    |
# |    explained_variance | 0.946    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2999     |
# |    policy_loss        | -0.701   |
# |    value_loss         | 0.895    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 93.1     |
# |    ep_rew_mean        | 20.1     |
# | time/                 |          |
# |    fps                | 234      |
# |    iterations         | 4000     |
# |    time_elapsed       | 85       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.662   |
# |    explained_variance | -0.973   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 3999     |
# |    policy_loss        | -0.289   |
# |    value_loss         | 1.5      |
# ------------------------------------
# iteration  1 : entropy 0.06469998479834042
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 102      |
# |    ep_rew_mean        | -43.8    |
# | time/                 |          |
# |    fps                | 227      |
# |    iterations         | 1000     |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -1.07    |
# |    explained_variance | 0.0202   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | -0.00151 |
# |    value_loss         | 0.000334 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 90.5     |
# |    ep_rew_mean        | -27.3    |
# | time/                 |          |
# |    fps                | 218      |
# |    iterations         | 2000     |
# |    time_elapsed       | 45       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.0742  |
# |    explained_variance | nan      |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | -0.00435 |
# |    value_loss         | 0.139    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 81.9     |
# |    ep_rew_mean        | 2.7      |
# | time/                 |          |
# |    fps                | 215      |
# |    iterations         | 3000     |
# |    time_elapsed       | 69       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.16    |
# |    explained_variance | 0.544    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.0111   |
# |    value_loss         | 0.912    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 101      |
# |    ep_rew_mean        | 23.3     |
# | time/                 |          |
# |    fps                | 215      |
# |    iterations         | 4000     |
# |    time_elapsed       | 92       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.0522  |
# |    explained_variance | 0.515    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 3999     |
# |    policy_loss        | 0.0147   |
# |    value_loss         | 2.16     |
# ------------------------------------
# iteration  2 : entropy 0.049100731289210234
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 87.2     |
# |    ep_rew_mean        | -43      |
# | time/                 |          |
# |    fps                | 224      |
# |    iterations         | 1000     |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -1.08    |
# |    explained_variance | 0.124    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | -0.0148  |
# |    value_loss         | 0.000326 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 80.9     |
# |    ep_rew_mean        | -30.6    |
# | time/                 |          |
# |    fps                | 223      |
# |    iterations         | 2000     |
# |    time_elapsed       | 44       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.329   |
# |    explained_variance | -60.5    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | 0.0532   |
# |    value_loss         | 17       |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 73.7     |
# |    ep_rew_mean        | -15.7    |
# | time/                 |          |
# |    fps                | 218      |
# |    iterations         | 3000     |
# |    time_elapsed       | 68       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.478   |
# |    explained_variance | 0.992    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.0142   |
# |    value_loss         | 0.313    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 79.3     |
# |    ep_rew_mean        | -3.7     |
# | time/                 |          |
# |    fps                | 211      |
# |    iterations         | 4000     |
# |    time_elapsed       | 94       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.302   |
# |    explained_variance | 0.201    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 3999     |
# |    policy_loss        | 0.598    |
# |    value_loss         | 6.39     |
# ------------------------------------
# iteration  3 : entropy 0.06576016445807657
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 83.9     |
# |    ep_rew_mean        | -45.9    |
# | time/                 |          |
# |    fps                | 295      |
# |    iterations         | 1000     |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -1.1     |
# |    explained_variance | -0.935   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | 0.0155   |
# |    value_loss         | 0.000243 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 97.3     |
# |    ep_rew_mean        | -40.8    |
# | time/                 |          |
# |    fps                | 286      |
# |    iterations         | 2000     |
# |    time_elapsed       | 34       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -1.09    |
# |    explained_variance | -0.353   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | -0.3     |
# |    value_loss         | 0.0827   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 106      |
# |    ep_rew_mean        | -33.5    |
# | time/                 |          |
# |    fps                | 277      |
# |    iterations         | 3000     |
# |    time_elapsed       | 54       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -1.08    |
# |    explained_variance | -0.122   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.0406   |
# |    value_loss         | 0.00444  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 98.5     |
# |    ep_rew_mean        | -30.4    |
# | time/                 |          |
# |    fps                | 283      |
# |    iterations         | 4000     |
# |    time_elapsed       | 70       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.869   |
# |    explained_variance | 0.987    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 3999     |
# |    policy_loss        | 0.1      |
# |    value_loss         | 0.27     |
# ------------------------------------
# iteration  4 : entropy 0.09934834412430484
# Using cpu device
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 92.3      |
# |    ep_rew_mean        | -44       |
# | time/                 |           |
# |    fps                | 265       |
# |    iterations         | 1000      |
# |    time_elapsed       | 18        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -1.03     |
# |    explained_variance | -6.57e+03 |
# |    learning_rate      | 0.001     |
# |    n_updates          | 999       |
# |    policy_loss        | 4.33      |
# |    value_loss         | 58.3      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 94       |
# |    ep_rew_mean        | -28.1    |
# | time/                 |          |
# |    fps                | 266      |
# |    iterations         | 2000     |
# |    time_elapsed       | 37       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.65    |
# |    explained_variance | -1.08    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | 0.0294   |
# |    value_loss         | 0.0451   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 96.9     |
# |    ep_rew_mean        | 6.1      |
# | time/                 |          |
# |    fps                | 257      |
# |    iterations         | 3000     |
# |    time_elapsed       | 58       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.293   |
# |    explained_variance | -191     |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2999     |
# |    policy_loss        | -0.0295  |
# |    value_loss         | 26.9     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 110      |
# |    ep_rew_mean        | 32.1     |
# | time/                 |          |
# |    fps                | 261      |
# |    iterations         | 4000     |
# |    time_elapsed       | 76       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.153   |
# |    explained_variance | 0.824    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 3999     |
# |    policy_loss        | -0.0163  |
# |    value_loss         | 0.25     |
# ------------------------------------
# iteration  5 : entropy 0.03145171571701679
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 84       |
# |    ep_rew_mean        | -45.4    |
# | time/                 |          |
# |    fps                | 222      |
# |    iterations         | 1000     |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -1.07    |
# |    explained_variance | 0.0508   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | -0.00096 |
# |    value_loss         | 7.31e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 74.6     |
# |    ep_rew_mean        | -21.5    |
# | time/                 |          |
# |    fps                | 247      |
# |    iterations         | 2000     |
# |    time_elapsed       | 40       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.334   |
# |    explained_variance | 0.268    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | 2.21     |
# |    value_loss         | 58.2     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 80.8      |
# |    ep_rew_mean        | 4.3       |
# | time/                 |           |
# |    fps                | 261       |
# |    iterations         | 3000      |
# |    time_elapsed       | 57        |
# |    total_timesteps    | 15000     |
# | train/                |           |
# |    entropy_loss       | -0.00246  |
# |    explained_variance | -1.84e+11 |
# |    learning_rate      | 0.001     |
# |    n_updates          | 2999      |
# |    policy_loss        | -0.000219 |
# |    value_loss         | 0.954     |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 107      |
# |    ep_rew_mean        | 27.7     |
# | time/                 |          |
# |    fps                | 268      |
# |    iterations         | 4000     |
# |    time_elapsed       | 74       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.101   |
# |    explained_variance | -0.155   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 3999     |
# |    policy_loss        | -0.00418 |
# |    value_loss         | 11.6     |
# ------------------------------------
# iteration  6 : entropy 0.0383709962837687
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 83       |
# |    ep_rew_mean        | -38.8    |
# | time/                 |          |
# |    fps                | 253      |
# |    iterations         | 1000     |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.943   |
# |    explained_variance | -0.0496  |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | -0.119   |
# |    value_loss         | 0.0192   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 69       |
# |    ep_rew_mean        | -9.5     |
# | time/                 |          |
# |    fps                | 236      |
# |    iterations         | 2000     |
# |    time_elapsed       | 42       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.108   |
# |    explained_variance | -7.29    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | 0.472    |
# |    value_loss         | 36.5     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 88.1     |
# |    ep_rew_mean        | 18.6     |
# | time/                 |          |
# |    fps                | 244      |
# |    iterations         | 3000     |
# |    time_elapsed       | 61       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.617   |
# |    explained_variance | -0.414   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2999     |
# |    policy_loss        | -0.595   |
# |    value_loss         | 1.6      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 104      |
# |    ep_rew_mean        | 28.5     |
# | time/                 |          |
# |    fps                | 240      |
# |    iterations         | 4000     |
# |    time_elapsed       | 82       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.176   |
# |    explained_variance | -0.293   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 3999     |
# |    policy_loss        | -0.0358  |
# |    value_loss         | 0.129    |
# ------------------------------------
# iteration  7 : entropy 0.028867031014121303
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 76.9     |
# |    ep_rew_mean        | -43.1    |
# | time/                 |          |
# |    fps                | 261      |
# |    iterations         | 1000     |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -1.08    |
# |    explained_variance | -0.717   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | -0.0553  |
# |    value_loss         | 0.00205  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 75.7      |
# |    ep_rew_mean        | -31.9     |
# | time/                 |           |
# |    fps                | 242       |
# |    iterations         | 2000      |
# |    time_elapsed       | 41        |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -0.964    |
# |    explained_variance | -1.07e+03 |
# |    learning_rate      | 0.001     |
# |    n_updates          | 1999      |
# |    policy_loss        | -37.7     |
# |    value_loss         | 1.99e+03  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 78.1     |
# |    ep_rew_mean        | -24.7    |
# | time/                 |          |
# |    fps                | 254      |
# |    iterations         | 3000     |
# |    time_elapsed       | 58       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -1.02    |
# |    explained_variance | 0.143    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.44     |
# |    value_loss         | 0.191    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 81       |
# |    ep_rew_mean        | -22.9    |
# | time/                 |          |
# |    fps                | 256      |
# |    iterations         | 4000     |
# |    time_elapsed       | 77       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.897   |
# |    explained_variance | 0.999    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 3999     |
# |    policy_loss        | 0.146    |
# |    value_loss         | 0.0739   |
# ------------------------------------
# iteration  8 : entropy 0.08054404933702784
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 79.9     |
# |    ep_rew_mean        | -45.2    |
# | time/                 |          |
# |    fps                | 304      |
# |    iterations         | 1000     |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -1.1     |
# |    explained_variance | 0.0829   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | -0.00561 |
# |    value_loss         | 0.000213 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 90.8     |
# |    ep_rew_mean        | -41.3    |
# | time/                 |          |
# |    fps                | 301      |
# |    iterations         | 2000     |
# |    time_elapsed       | 33       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -1.07    |
# |    explained_variance | 0.361    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | -0.00583 |
# |    value_loss         | 7.03e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 82.1     |
# |    ep_rew_mean        | -23.1    |
# | time/                 |          |
# |    fps                | 295      |
# |    iterations         | 3000     |
# |    time_elapsed       | 50       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.621   |
# |    explained_variance | 0.561    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.0857   |
# |    value_loss         | 0.158    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 69.4     |
# |    ep_rew_mean        | -11.4    |
# | time/                 |          |
# |    fps                | 288      |
# |    iterations         | 4000     |
# |    time_elapsed       | 69       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.907   |
# |    explained_variance | 0.117    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 3999     |
# |    policy_loss        | 8.18     |
# |    value_loss         | 79       |
# ------------------------------------
# iteration  9 : entropy 0.09411298688522297
# entropy 0.027588144086158686
# Max Train Score 19 Max Test Score 24
# Mean Train Score 2.6565167757521153 Mean Test Score 3.7677387680878436
# ----------------------------------------------------------------------------------------------------
# entropy 0.06469998479834042
# Max Train Score 22 Max Test Score 29
# Mean Train Score 2.2352480211875734 Mean Test Score 5.623993226939822
# ----------------------------------------------------------------------------------------------------
# entropy 0.049100731289210234
# Max Train Score 21 Max Test Score 28
# Mean Train Score 2.5307229756745313 Mean Test Score 5.251667872549002
# ----------------------------------------------------------------------------------------------------
# entropy 0.06576016445807657
# Max Train Score 12 Max Test Score 19
# Mean Train Score 1.7515621284368479 Mean Test Score 4.249339912511456
# ----------------------------------------------------------------------------------------------------
# entropy 0.09934834412430484
# Max Train Score 5 Max Test Score 6
# Mean Train Score 0.89959687239 Mean Test Score 1.3638151456759453
# ----------------------------------------------------------------------------------------------------
# entropy 0.03145171571701679
# Max Train Score 23 Max Test Score 33
# Mean Train Score 2.7401153036186754 Mean Test Score 7.067491104714738
# ----------------------------------------------------------------------------------------------------
# entropy 0.0383709962837687
# Max Train Score 28 Max Test Score 23
# Mean Train Score 2.5184246503654877 Mean Test Score 6.06822675085481
# ----------------------------------------------------------------------------------------------------
# entropy 0.028867031014121303
# Max Train Score 21 Max Test Score 17
# Mean Train Score 2.7991533204015746 Mean Test Score 3.448095259630329
# ----------------------------------------------------------------------------------------------------
# entropy 0.08054404933702784
# Max Train Score 6 Max Test Score 6
# Mean Train Score 1.2303003639238899 Mean Test Score 1.5413768585949816
# ----------------------------------------------------------------------------------------------------
# entropy 0.09411298688522297
# Max Train Score 10 Max Test Score 11
# Mean Train Score 1.3286993355777386 Mean Test Score 2.1367135922081104
# ----------------------------------------------------------------------------------------------------

# %%
formatted_dict = {'entropy': [],
                  'metrics': [],
                  'results': []}

for entropy, result in results.items():
    _, max_train_score, max_test_score, mean_train_score, mean_test_score = result

    formatted_dict['entropy'].append(entropy)
    formatted_dict['metrics'].append('Max Train Score')
    formatted_dict['results'].append(max_train_score)

    formatted_dict['entropy'].append(entropy)
    formatted_dict['metrics'].append('Max Test Score')
    formatted_dict['results'].append(max_test_score)
    
    formatted_dict['entropy'].append(entropy)
    formatted_dict['metrics'].append('Mean Train Score')
    formatted_dict['results'].append(mean_train_score)

    formatted_dict['entropy'].append(entropy)
    formatted_dict['metrics'].append('Mean Test Score')
    formatted_dict['results'].append(mean_test_score)

df_metrics = pd.DataFrame(formatted_dict)
sns.lineplot(data=df_metrics, x='entropy', y='results', hue='metrics')
# Out:
# <AxesSubplot:xlabel='entropy', ylabel='results'>

# %% [markdown]
# ### Testando: vf_coef

# %%
results = {}
for i in range(50):
    # enable_render=True turns on the display
    snake_env = SnakeEnv(440, 440, enable_render=False)
    env = make_vec_env(lambda: snake_env, n_envs=1)

    vf_coef = random.uniform(0, 1)
    
    model = A2C(MlpPolicy, env, verbose=1, learning_rate=1e-3, seed=42, gamma=0.98, ent_coef=0.06, vf_coef=vf_coef)
    model.learn(total_timesteps=20000, log_interval=1000)

    # Print rewards and scores for each episode
    max_train_score = snake_env.record
    mean_train_score = np.mean(np.array(snake_env.results['score']))
    max_test_score, mean_test_score = evaluate(model)
    print("iteration ", i, ": vf_coef", vf_coef)
    results[vf_coef] = (snake_env.results, max_train_score, max_test_score, mean_train_score, mean_test_score)
    
for entropy, result in results.items():
    metrics, max_train_score, max_test_score, mean_train_score, mean_test_score = result
    
    print("vf_coef", vf_coef)
    plot_metrics(metrics)    
    print("Max Train Score", max_train_score, "Max Test Score", max_test_score)
    print("Mean Train Score", mean_train_score, "Mean Test Score", mean_test_score)
    print("-"*100)
# Out:
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 90.8     |
# |    ep_rew_mean        | -44.1    |
# | time/                 |          |
# |    fps                | 204      |
# |    iterations         | 1000     |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -1.07    |
# |    explained_variance | 0.00165  |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | -0.0369  |
# |    value_loss         | 0.00134  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 84       |
# |    ep_rew_mean        | -32.1    |
# | time/                 |          |
# |    fps                | 210      |
# |    iterations         | 2000     |
# |    time_elapsed       | 47       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.524   |
# |    explained_variance | 0.742    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | 0.024    |
# |    value_loss         | 6.17     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 76.3     |
# |    ep_rew_mean        | -18.8    |
# | time/                 |          |
# |    fps                | 217      |
# |    iterations         | 3000     |
# |    time_elapsed       | 68       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.16    |
# |    explained_variance | 0.606    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.0593   |
# |    value_loss         | 6.2      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 83.3     |
# |    ep_rew_mean        | -4       |
# | time/                 |          |
# |    fps                | 210      |
# |    iterations         | 4000     |
# |    time_elapsed       | 94       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.0227  |
# |    explained_variance | -418     |
# |    learning_rate      | 0.001    |
# |    n_updates          | 3999     |
# |    policy_loss        | 0.0114   |
# |    value_loss         | 74.8     |
# ------------------------------------
# iteration  0 : vf_coef 0.6609192214581366
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 97.2     |
# |    ep_rew_mean        | -38.6    |
# | time/                 |          |
# |    fps                | 197      |
# |    iterations         | 1000     |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -1.07    |
# |    explained_variance | 0.0816   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | 0.00148  |
# |    value_loss         | 0.00027  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 82.6     |
# |    ep_rew_mean        | -18.8    |
# | time/                 |          |
# |    fps                | 211      |
# |    iterations         | 2000     |
# |    time_elapsed       | 47       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.556   |
# |    explained_variance | 0.227    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | 0.503    |
# |    value_loss         | 2.43     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 89.8     |
# |    ep_rew_mean        | 9.7      |
# | time/                 |          |
# |    fps                | 210      |
# |    iterations         | 3000     |
# |    time_elapsed       | 71       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.0412  |
# |    explained_variance | nan      |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2999     |
# |    policy_loss        | -0.00591 |
# |    value_loss         | 1.13     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 108      |
# |    ep_rew_mean        | 29.3     |
# | time/                 |          |
# |    fps                | 209      |
# |    iterations         | 4000     |
# |    time_elapsed       | 95       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.271   |
# |    explained_variance | -91.8    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 3999     |
# |    policy_loss        | 0.349    |
# |    value_loss         | 16.9     |
# ------------------------------------
# iteration  1 : vf_coef 0.3281176377422065
# Using cpu device
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 84.1      |
# |    ep_rew_mean        | -44.5     |
# | time/                 |           |
# |    fps                | 195       |
# |    iterations         | 1000      |
# |    time_elapsed       | 25        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -1.08     |
# |    explained_variance | -4.18e+05 |
# |    learning_rate      | 0.001     |
# |    n_updates          | 999       |
# |    policy_loss        | 5.22      |
# |    value_loss         | 57.8      |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 86.7      |
# |    ep_rew_mean        | -34.3     |
# | time/                 |           |
# |    fps                | 207       |
# |    iterations         | 2000      |
# |    time_elapsed       | 48        |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -0.0668   |
# |    explained_variance | -1.93e+11 |
# |    learning_rate      | 0.001     |
# |    n_updates          | 1999      |
# |    policy_loss        | -0.00246  |
# |    value_loss         | 0.0628    |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 70       |
# |    ep_rew_mean        | -13.9    |
# | time/                 |          |
# |    fps                | 206      |
# |    iterations         | 3000     |
# |    time_elapsed       | 72       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.333   |
# |    explained_variance | -6.09    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.0126   |
# |    value_loss         | 9.7      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 79.7     |
# |    ep_rew_mean        | 2.6      |
# | time/                 |          |
# |    fps                | 205      |
# |    iterations         | 4000     |
# |    time_elapsed       | 97       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.0488  |
# |    explained_variance | 0.57     |
# |    learning_rate      | 0.001    |
# |    n_updates          | 3999     |
# |    policy_loss        | 0.00839  |
# |    value_loss         | 0.964    |
# ------------------------------------
# iteration  2 : vf_coef 0.7958808896024273
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 95.6     |
# |    ep_rew_mean        | -44.7    |
# | time/                 |          |
# |    fps                | 205      |
# |    iterations         | 1000     |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -1.1     |
# |    explained_variance | 0.103    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | 0.0201   |
# |    value_loss         | 0.000822 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 83.5     |
# |    ep_rew_mean        | -29.3    |
# | time/                 |          |
# |    fps                | 197      |
# |    iterations         | 2000     |
# |    time_elapsed       | 50       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.92    |
# |    explained_variance | -2.4     |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | -0.0734  |
# |    value_loss         | 0.00487  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 64.4     |
# |    ep_rew_mean        | -10.6    |
# | time/                 |          |
# |    fps                | 198      |
# |    iterations         | 3000     |
# |    time_elapsed       | 75       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.575   |
# |    explained_variance | 0.0524   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2999     |
# |    policy_loss        | 3.46     |
# |    value_loss         | 30.6     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 80       |
# |    ep_rew_mean        | 1.5      |
# | time/                 |          |
# |    fps                | 202      |
# |    iterations         | 4000     |
# |    time_elapsed       | 98       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.154   |
# |    explained_variance | 0.311    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 3999     |
# |    policy_loss        | 0.431    |
# |    value_loss         | 129      |
# ------------------------------------
# iteration  3 : vf_coef 0.3005009537574196
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 80       |
# |    ep_rew_mean        | -46.4    |
# | time/                 |          |
# |    fps                | 218      |
# |    iterations         | 1000     |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -1.09    |
# |    explained_variance | -0.438   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | 0.0234   |
# |    value_loss         | 0.0011   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 80.3     |
# |    ep_rew_mean        | -33      |
# | time/                 |          |
# |    fps                | 205      |
# |    iterations         | 2000     |
# |    time_elapsed       | 48       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.945   |
# |    explained_variance | 0.424    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | 0.00833  |
# |    value_loss         | 0.000207 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 74       |
# |    ep_rew_mean        | -4.9     |
# | time/                 |          |
# |    fps                | 208      |
# |    iterations         | 3000     |
# |    time_elapsed       | 72       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.418   |
# |    explained_variance | -2.51    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.194    |
# |    value_loss         | 27.7     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 99.9     |
# |    ep_rew_mean        | 23.6     |
# | time/                 |          |
# |    fps                | 208      |
# |    iterations         | 4000     |
# |    time_elapsed       | 96       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.0364  |
# |    explained_variance | -1.19    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 3999     |
# |    policy_loss        | -0.00373 |
# |    value_loss         | 2.67     |
# ------------------------------------
# iteration  4 : vf_coef 0.5625247274643543
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 90.1     |
# |    ep_rew_mean        | -44      |
# | time/                 |          |
# |    fps                | 184      |
# |    iterations         | 1000     |
# |    time_elapsed       | 27       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -1.05    |
# |    explained_variance | 0.0749   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | -0.0481  |
# |    value_loss         | 0.00392  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 93.5     |
# |    ep_rew_mean        | -35.2    |
# | time/                 |          |
# |    fps                | 190      |
# |    iterations         | 2000     |
# |    time_elapsed       | 52       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.939   |
# |    explained_variance | 0.687    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | -0.0292  |
# |    value_loss         | 0.000504 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 80.7     |
# |    ep_rew_mean        | -16.4    |
# | time/                 |          |
# |    fps                | 195      |
# |    iterations         | 3000     |
# |    time_elapsed       | 76       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.203   |
# |    explained_variance | 0.609    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.00229  |
# |    value_loss         | 0.131    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 87.8     |
# |    ep_rew_mean        | 6.3      |
# | time/                 |          |
# |    fps                | 195      |
# |    iterations         | 4000     |
# |    time_elapsed       | 102      |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.156   |
# |    explained_variance | -27.6    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 3999     |
# |    policy_loss        | 0.108    |
# |    value_loss         | 70.9     |
# ------------------------------------
# iteration  5 : vf_coef 0.6576016445807656
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 95.6     |
# |    ep_rew_mean        | -44.7    |
# | time/                 |          |
# |    fps                | 216      |
# |    iterations         | 1000     |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -1.1     |
# |    explained_variance | 0.103    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | 0.0201   |
# |    value_loss         | 0.000821 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 94.2     |
# |    ep_rew_mean        | -30.3    |
# | time/                 |          |
# |    fps                | 215      |
# |    iterations         | 2000     |
# |    time_elapsed       | 46       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.375   |
# |    explained_variance | -3.43    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | 0.517    |
# |    value_loss         | 57.4     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 82.8     |
# |    ep_rew_mean        | 1.3      |
# | time/                 |          |
# |    fps                | 208      |
# |    iterations         | 3000     |
# |    time_elapsed       | 72       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.109   |
# |    explained_variance | -0.297   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2999     |
# |    policy_loss        | -0.0284  |
# |    value_loss         | 2.84     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 98.2     |
# |    ep_rew_mean        | 22.9     |
# | time/                 |          |
# |    fps                | 208      |
# |    iterations         | 4000     |
# |    time_elapsed       | 95       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.14    |
# |    explained_variance | 0.236    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 3999     |
# |    policy_loss        | 0.503    |
# |    value_loss         | 6.23     |
# ------------------------------------
# iteration  6 : vf_coef 0.30176443514420326
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 101      |
# |    ep_rew_mean        | -40.4    |
# | time/                 |          |
# |    fps                | 211      |
# |    iterations         | 1000     |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -1.04    |
# |    explained_variance | -1.52    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | 0.11     |
# |    value_loss         | 0.0151   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 73       |
# |    ep_rew_mean        | -19.3    |
# | time/                 |          |
# |    fps                | 200      |
# |    iterations         | 2000     |
# |    time_elapsed       | 49       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.0701  |
# |    explained_variance | -27.1    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | 0.0297   |
# |    value_loss         | 12.4     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 73.3     |
# |    ep_rew_mean        | 0.2      |
# | time/                 |          |
# |    fps                | 202      |
# |    iterations         | 3000     |
# |    time_elapsed       | 74       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.782   |
# |    explained_variance | -59.8    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2999     |
# |    policy_loss        | -0.228   |
# |    value_loss         | 0.169    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 94       |
# |    ep_rew_mean        | 17.4     |
# | time/                 |          |
# |    fps                | 205      |
# |    iterations         | 4000     |
# |    time_elapsed       | 97       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.25    |
# |    explained_variance | -1.61    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 3999     |
# |    policy_loss        | -0.0373  |
# |    value_loss         | 0.533    |
# ------------------------------------
# iteration  7 : vf_coef 0.2759618716024036
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 86       |
# |    ep_rew_mean        | -43      |
# | time/                 |          |
# |    fps                | 199      |
# |    iterations         | 1000     |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.676   |
# |    explained_variance | -0.075   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | -0.0865  |
# |    value_loss         | 0.0159   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 90       |
# |    ep_rew_mean        | -32      |
# | time/                 |          |
# |    fps                | 195      |
# |    iterations         | 2000     |
# |    time_elapsed       | 51       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -1.05    |
# |    explained_variance | -167     |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | -55.5    |
# |    value_loss         | 2.35e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 76.9     |
# |    ep_rew_mean        | -20.4    |
# | time/                 |          |
# |    fps                | 188      |
# |    iterations         | 3000     |
# |    time_elapsed       | 79       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.893   |
# |    explained_variance | 0.00387  |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2999     |
# |    policy_loss        | -0.228   |
# |    value_loss         | 0.04     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 75.2     |
# |    ep_rew_mean        | -16.7    |
# | time/                 |          |
# |    fps                | 194      |
# |    iterations         | 4000     |
# |    time_elapsed       | 102      |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.145   |
# |    explained_variance | -87.6    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 3999     |
# |    policy_loss        | -0.0193  |
# |    value_loss         | 0.498    |
# ------------------------------------
# iteration  8 : vf_coef 0.8626365474573073
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 97.2     |
# |    ep_rew_mean        | -38.6    |
# | time/                 |          |
# |    fps                | 219      |
# |    iterations         | 1000     |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -1.07    |
# |    explained_variance | 0.0816   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | 0.00155  |
# |    value_loss         | 0.000268 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 74.5     |
# |    ep_rew_mean        | -14.9    |
# | time/                 |          |
# |    fps                | 212      |
# |    iterations         | 2000     |
# |    time_elapsed       | 46       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.106   |
# |    explained_variance | -108     |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | 0.0632   |
# |    value_loss         | 77.5     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 87.9     |
# |    ep_rew_mean        | 14.2     |
# | time/                 |          |
# |    fps                | 213      |
# |    iterations         | 3000     |
# |    time_elapsed       | 70       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.333   |
# |    explained_variance | -10.6    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2999     |
# |    policy_loss        | -0.148   |
# |    value_loss         | 0.715    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 109      |
# |    ep_rew_mean        | 34.1     |
# | time/                 |          |
# |    fps                | 209      |
# |    iterations         | 4000     |
# |    time_elapsed       | 95       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.267   |
# |    explained_variance | -0.307   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 3999     |
# |    policy_loss        | -0.318   |
# |    value_loss         | 18.2     |
# ------------------------------------
# iteration  9 : vf_coef 0.33192468638134454
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 92.1     |
# |    ep_rew_mean        | -36.9    |
# | time/                 |          |
# |    fps                | 204      |
# |    iterations         | 1000     |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.948   |
# |    explained_variance | -0.207   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | -0.0667  |
# |    value_loss         | 0.021    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 74.3     |
# |    ep_rew_mean        | -11.6    |
# | time/                 |          |
# |    fps                | 210      |
# |    iterations         | 2000     |
# |    time_elapsed       | 47       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.154   |
# |    explained_variance | -10.7    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | 1.18     |
# |    value_loss         | 82.1     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 83.7      |
# |    ep_rew_mean        | 16.5      |
# | time/                 |           |
# |    fps                | 206       |
# |    iterations         | 3000      |
# |    time_elapsed       | 72        |
# |    total_timesteps    | 15000     |
# | train/                |           |
# |    entropy_loss       | -0.189    |
# |    explained_variance | -1.86e+11 |
# |    learning_rate      | 0.001     |
# |    n_updates          | 2999      |
# |    policy_loss        | -0.0349   |
# |    value_loss         | 0.968     |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 114      |
# |    ep_rew_mean        | 39.5     |
# | time/                 |          |
# |    fps                | 208      |
# |    iterations         | 4000     |
# |    time_elapsed       | 95       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.232   |
# |    explained_variance | -5.98    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 3999     |
# |    policy_loss        | -0.0794  |
# |    value_loss         | 13.2     |
# ------------------------------------
# iteration  10 : vf_coef 0.31450366818216935
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 92.8     |
# |    ep_rew_mean        | -44.9    |
# | time/                 |          |
# |    fps                | 191      |
# |    iterations         | 1000     |
# |    time_elapsed       | 26       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -1.09    |
# |    explained_variance | -0.282   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | 0.00125  |
# |    value_loss         | 6.48e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 81.6     |
# |    ep_rew_mean        | -34.1    |
# | time/                 |          |
# |    fps                | 197      |
# |    iterations         | 2000     |
# |    time_elapsed       | 50       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.833   |
# |    explained_variance | 0.00492  |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | -0.0471  |
# |    value_loss         | 0.0256   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 62.9     |
# |    ep_rew_mean        | -17.1    |
# | time/                 |          |
# |    fps                | 201      |
# |    iterations         | 3000     |
# |    time_elapsed       | 74       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.587   |
# |    explained_variance | -2.6     |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2999     |
# |    policy_loss        | -0.208   |
# |    value_loss         | 0.182    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 81.8     |
# |    ep_rew_mean        | 3        |
# | time/                 |          |
# |    fps                | 201      |
# |    iterations         | 4000     |
# |    time_elapsed       | 99       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.315   |
# |    explained_variance | nan      |
# |    learning_rate      | 0.001    |
# |    n_updates          | 3999     |
# |    policy_loss        | -0.0265  |
# |    value_loss         | 0.128    |
# ------------------------------------
# iteration  11 : vf_coef 0.9311600771571855
# Using cpu device
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 99.5      |
# |    ep_rew_mean        | -41.2     |
# | time/                 |           |
# |    fps                | 211       |
# |    iterations         | 1000      |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -1        |
# |    explained_variance | 0.0175    |
# |    learning_rate      | 0.001     |
# |    n_updates          | 999       |
# |    policy_loss        | -5.08e-05 |
# |    value_loss         | 0.00257   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 87.4     |
# |    ep_rew_mean        | -20.1    |
# | time/                 |          |
# |    fps                | 207      |
# |    iterations         | 2000     |
# |    time_elapsed       | 48       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.691   |
# |    explained_variance | 0.265    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | 0.103    |
# |    value_loss         | 0.197    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 89.5     |
# |    ep_rew_mean        | 14.3     |
# | time/                 |          |
# |    fps                | 198      |
# |    iterations         | 3000     |
# |    time_elapsed       | 75       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.148   |
# |    explained_variance | 0.676    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.0192   |
# |    value_loss         | 0.37     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 113      |
# |    ep_rew_mean        | 38.4     |
# | time/                 |          |
# |    fps                | 198      |
# |    iterations         | 4000     |
# |    time_elapsed       | 100      |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.193   |
# |    explained_variance | 0.749    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 3999     |
# |    policy_loss        | 0.0161   |
# |    value_loss         | 0.154    |
# ------------------------------------
# iteration  12 : vf_coef 0.37070492143125844
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 90.1     |
# |    ep_rew_mean        | -44      |
# | time/                 |          |
# |    fps                | 177      |
# |    iterations         | 1000     |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -1.05    |
# |    explained_variance | 0.0748   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | -0.0482  |
# |    value_loss         | 0.00394  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 93.5     |
# |    ep_rew_mean        | -35.2    |
# | time/                 |          |
# |    fps                | 179      |
# |    iterations         | 2000     |
# |    time_elapsed       | 55       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.939   |
# |    explained_variance | 0.687    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | -0.0293  |
# |    value_loss         | 0.000506 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 80.9     |
# |    ep_rew_mean        | -16.7    |
# | time/                 |          |
# |    fps                | 183      |
# |    iterations         | 3000     |
# |    time_elapsed       | 81       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.971   |
# |    explained_variance | 0.329    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.564    |
# |    value_loss         | 0.547    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 86.2     |
# |    ep_rew_mean        | 6.7      |
# | time/                 |          |
# |    fps                | 184      |
# |    iterations         | 4000     |
# |    time_elapsed       | 108      |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.609   |
# |    explained_variance | -1.81    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 3999     |
# |    policy_loss        | -1.08    |
# |    value_loss         | 0.576    |
# ------------------------------------
# iteration  13 : vf_coef 0.655485228383535
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 88.7     |
# |    ep_rew_mean        | -46.4    |
# | time/                 |          |
# |    fps                | 201      |
# |    iterations         | 1000     |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -1.09    |
# |    explained_variance | -0.437   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | 0.00368  |
# |    value_loss         | 1.28e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 81.1     |
# |    ep_rew_mean        | -24.2    |
# | time/                 |          |
# |    fps                | 197      |
# |    iterations         | 2000     |
# |    time_elapsed       | 50       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.148   |
# |    explained_variance | -2.88    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | 0.118    |
# |    value_loss         | 33.5     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 72.9     |
# |    ep_rew_mean        | 2.2      |
# | time/                 |          |
# |    fps                | 193      |
# |    iterations         | 3000     |
# |    time_elapsed       | 77       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.477   |
# |    explained_variance | -31.2    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2999     |
# |    policy_loss        | -25.5    |
# |    value_loss         | 1.15e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 95.9     |
# |    ep_rew_mean        | 18.4     |
# | time/                 |          |
# |    fps                | 202      |
# |    iterations         | 4000     |
# |    time_elapsed       | 98       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.498   |
# |    explained_variance | -0.363   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 3999     |
# |    policy_loss        | -15.4    |
# |    value_loss         | 3.15e+03 |
# ------------------------------------
# iteration  14 : vf_coef 0.1492176078251637
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 84.9     |
# |    ep_rew_mean        | -45.3    |
# | time/                 |          |
# |    fps                | 265      |
# |    iterations         | 1000     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -1.04    |
# |    explained_variance | 0.0065   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | -0.0228  |
# |    value_loss         | 0.00123  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 83.7     |
# |    ep_rew_mean        | -29.6    |
# | time/                 |          |
# |    fps                | 307      |
# |    iterations         | 2000     |
# |    time_elapsed       | 32       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.598   |
# |    explained_variance | 0.207    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | -0.154   |
# |    value_loss         | 3.72     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 77.8     |
# |    ep_rew_mean        | -6.6     |
# | time/                 |          |
# |    fps                | 320      |
# |    iterations         | 3000     |
# |    time_elapsed       | 46       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.423   |
# |    explained_variance | 0.254    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2999     |
# |    policy_loss        | 3.23     |
# |    value_loss         | 23.7     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 96.9     |
# |    ep_rew_mean        | 14.5     |
# | time/                 |          |
# |    fps                | 329      |
# |    iterations         | 4000     |
# |    time_elapsed       | 60       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.0938  |
# |    explained_variance | 0.391    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 3999     |
# |    policy_loss        | 0.00578  |
# |    value_loss         | 0.502    |
# ------------------------------------
# iteration  15 : vf_coef 0.1998000487106072
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 79       |
# |    ep_rew_mean        | -43.5    |
# | time/                 |          |
# |    fps                | 280      |
# |    iterations         | 1000     |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -1.05    |
# |    explained_variance | -0.0437  |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | -0.0536  |
# |    value_loss         | 0.00457  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 77.9     |
# |    ep_rew_mean        | -32      |
# | time/                 |          |
# |    fps                | 259      |
# |    iterations         | 2000     |
# |    time_elapsed       | 38       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -1.03    |
# |    explained_variance | -0.494   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | -0.0483  |
# |    value_loss         | 0.00372  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 71.4      |
# |    ep_rew_mean        | -21.1     |
# | time/                 |           |
# |    fps                | 269       |
# |    iterations         | 3000      |
# |    time_elapsed       | 55        |
# |    total_timesteps    | 15000     |
# | train/                |           |
# |    entropy_loss       | -1.05     |
# |    explained_variance | -0.000689 |
# |    learning_rate      | 0.001     |
# |    n_updates          | 2999      |
# |    policy_loss        | -0.0584   |
# |    value_loss         | 0.021     |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 77.8     |
# |    ep_rew_mean        | -14.3    |
# | time/                 |          |
# |    fps                | 261      |
# |    iterations         | 4000     |
# |    time_elapsed       | 76       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.646   |
# |    explained_variance | 0.996    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 3999     |
# |    policy_loss        | 0.0776   |
# |    value_loss         | 0.189    |
# ------------------------------------
# iteration  16 : vf_coef 0.9614691898760058
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 86.3     |
# |    ep_rew_mean        | -43.9    |
# | time/                 |          |
# |    fps                | 367      |
# |    iterations         | 1000     |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -1.09    |
# |    explained_variance | -0.386   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | 0.000591 |
# |    value_loss         | 2.72e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 81.3     |
# |    ep_rew_mean        | -33.2    |
# | time/                 |          |
# |    fps                | 363      |
# |    iterations         | 2000     |
# |    time_elapsed       | 27       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.923   |
# |    explained_variance | -0.65    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | 0.114    |
# |    value_loss         | 0.0301   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 67       |
# |    ep_rew_mean        | -16.6    |
# | time/                 |          |
# |    fps                | 363      |
# |    iterations         | 3000     |
# |    time_elapsed       | 41       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.262   |
# |    explained_variance | -9.94    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.113    |
# |    value_loss         | 16.4     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 84       |
# |    ep_rew_mean        | 6.6      |
# | time/                 |          |
# |    fps                | 328      |
# |    iterations         | 4000     |
# |    time_elapsed       | 60       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.129   |
# |    explained_variance | 0.425    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 3999     |
# |    policy_loss        | 0.357    |
# |    value_loss         | 144      |
# ------------------------------------
# iteration  17 : vf_coef 0.8946374949550533
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 78.7     |
# |    ep_rew_mean        | -41.7    |
# | time/                 |          |
# |    fps                | 243      |
# |    iterations         | 1000     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.944   |
# |    explained_variance | -535     |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | 3.79     |
# |    value_loss         | 52.8     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 72       |
# |    ep_rew_mean        | -21.8    |
# | time/                 |          |
# |    fps                | 245      |
# |    iterations         | 2000     |
# |    time_elapsed       | 40       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.88    |
# |    explained_variance | 0.0241   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | -1.52    |
# |    value_loss         | 1.75     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 77.4     |
# |    ep_rew_mean        | -5.8     |
# | time/                 |          |
# |    fps                | 244      |
# |    iterations         | 3000     |
# ...
# |    policy_loss        | 2.02     |
# |    value_loss         | 51.9     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 86.3     |
# |    ep_rew_mean        | -9.5     |
# | time/                 |          |
# |    fps                | 341      |
# |    iterations         | 3000     |
# |    time_elapsed       | 43       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.857   |
# |    explained_variance | 0.156    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2999     |
# |    policy_loss        | -0.49    |
# |    value_loss         | 0.402    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 91.7     |
# |    ep_rew_mean        | 14.3     |
# | time/                 |          |
# |    fps                | 348      |
# |    iterations         | 4000     |
# |    time_elapsed       | 57       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.641   |
# |    explained_variance | -1.76    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 3999     |
# |    policy_loss        | -0.354   |
# |    value_loss         | 0.647    |
# ------------------------------------
# iteration  47 : vf_coef 0.8087297886312608
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 90.1     |
# |    ep_rew_mean        | -44.7    |
# | time/                 |          |
# |    fps                | 344      |
# |    iterations         | 1000     |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -1.1     |
# |    explained_variance | 0.172    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | -0.00124 |
# |    value_loss         | 3.5e-05  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 87.3     |
# |    ep_rew_mean        | -33.3    |
# | time/                 |          |
# |    fps                | 358      |
# |    iterations         | 2000     |
# |    time_elapsed       | 27       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -1.05    |
# |    explained_variance | -0.182   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | -0.0161  |
# |    value_loss         | 0.000474 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 68.3     |
# |    ep_rew_mean        | -16.9    |
# | time/                 |          |
# |    fps                | 361      |
# |    iterations         | 3000     |
# |    time_elapsed       | 41       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -1.08    |
# |    explained_variance | 0.417    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.0156   |
# |    value_loss         | 0.00207  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 77.2     |
# |    ep_rew_mean        | -5.8     |
# | time/                 |          |
# |    fps                | 362      |
# |    iterations         | 4000     |
# |    time_elapsed       | 55       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.752   |
# |    explained_variance | nan      |
# |    learning_rate      | 0.001    |
# |    n_updates          | 3999     |
# |    policy_loss        | -0.0388  |
# |    value_loss         | 0.0186   |
# ------------------------------------
# iteration  48 : vf_coef 0.4760051001318911
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 104      |
# |    ep_rew_mean        | -44      |
# | time/                 |          |
# |    fps                | 252      |
# |    iterations         | 1000     |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -1.07    |
# |    explained_variance | -0.177   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | -0.0379  |
# |    value_loss         | 0.00244  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 86.5     |
# |    ep_rew_mean        | -22.1    |
# | time/                 |          |
# |    fps                | 297      |
# |    iterations         | 2000     |
# |    time_elapsed       | 33       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.397   |
# |    explained_variance | 0.268    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | 0.0928   |
# |    value_loss         | 3.16     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 77.7     |
# |    ep_rew_mean        | 6.6      |
# | time/                 |          |
# |    fps                | 312      |
# |    iterations         | 3000     |
# |    time_elapsed       | 48       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.0514  |
# |    explained_variance | nan      |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2999     |
# |    policy_loss        | -0.0088  |
# |    value_loss         | 1.5      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 84       |
# |    ep_rew_mean        | 11       |
# | time/                 |          |
# |    fps                | 321      |
# |    iterations         | 4000     |
# |    time_elapsed       | 62       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.0829  |
# |    explained_variance | -1.73    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 3999     |
# |    policy_loss        | -0.0121  |
# |    value_loss         | 1.57     |
# ------------------------------------
# iteration  49 : vf_coef 0.06175804755668379
# vf_coef 0.06175804755668379
# Max Train Score 13 Max Test Score 22
# Mean Train Score 1.7178732356506208 Mean Test Score 4.906122214350749
# ----------------------------------------------------------------------------------------------------
# vf_coef 0.06175804755668379
# Max Train Score 23 Max Test Score 35
# Mean Train Score 2.7901054304603456 Mean Test Score 6.008247133195176
# ----------------------------------------------------------------------------------------------------
# vf_coef 0.06175804755668379
# Max Train Score 16 Max Test Score 17
# Mean Train Score 1.7905845149368098 Mean Test Score 3.227835122290369
# ----------------------------------------------------------------------------------------------------
# vf_coef 0.06175804755668379
# Max Train Score 14 Max Test Score 22
# Mean Train Score 1.955651624564859 Mean Test Score 4.4114797251633275
# ----------------------------------------------------------------------------------------------------
# vf_coef 0.06175804755668379
# Max Train Score 25 Max Test Score 31
# Mean Train Score 2.2602882157299193 Mean Test Score 6.056178713579266
# ----------------------------------------------------------------------------------------------------
# vf_coef 0.06175804755668379
# Max Train Score 16 Max Test Score 23
# Mean Train Score 1.901739347415207 Mean Test Score 4.859124301864453
# ----------------------------------------------------------------------------------------------------
# vf_coef 0.06175804755668379
# Max Train Score 23 Max Test Score 21
# Mean Train Score 2.483187032733597 Mean Test Score 5.208599674887313
# ----------------------------------------------------------------------------------------------------
# vf_coef 0.06175804755668379
# Max Train Score 21 Max Test Score 17
# Mean Train Score 2.4135017876390275 Mean Test Score 3.947712663328662
# ----------------------------------------------------------------------------------------------------
# vf_coef 0.06175804755668379
# Max Train Score 8 Max Test Score 13
# Mean Train Score 1.4605117027447656 Mean Test Score 2.231488914492677
# ----------------------------------------------------------------------------------------------------
# vf_coef 0.06175804755668379
# Max Train Score 22 Max Test Score 21
# Mean Train Score 2.839808450583385 Mean Test Score 4.942504521811902
# ----------------------------------------------------------------------------------------------------
# vf_coef 0.06175804755668379
# Max Train Score 22 Max Test Score 27
# Mean Train Score 3.0583926017549974 Mean Test Score 6.029887406478991
# ----------------------------------------------------------------------------------------------------
# vf_coef 0.06175804755668379
# Max Train Score 14 Max Test Score 19
# Mean Train Score 1.7989242270900279 Mean Test Score 4.262728829415234
# ----------------------------------------------------------------------------------------------------
# vf_coef 0.06175804755668379
# Max Train Score 25 Max Test Score 28
# Mean Train Score 2.9343222785308565 Mean Test Score 5.943102334870665
# ----------------------------------------------------------------------------------------------------
# vf_coef 0.06175804755668379
# Max Train Score 17 Max Test Score 23
# Mean Train Score 1.9199325846323385 Mean Test Score 5.301452998828485
# ----------------------------------------------------------------------------------------------------
# vf_coef 0.06175804755668379
# Max Train Score 17 Max Test Score 19
# Mean Train Score 2.326930443590284 Mean Test Score 4.163924718074459
# ----------------------------------------------------------------------------------------------------
# vf_coef 0.06175804755668379
# Max Train Score 25 Max Test Score 32
# Mean Train Score 2.1399450825271495 Mean Test Score 5.913058563693646
# ----------------------------------------------------------------------------------------------------
# vf_coef 0.06175804755668379
# Max Train Score 9 Max Test Score 11
# Mean Train Score 1.4505564737604855 Mean Test Score 2.1886508463020564
# ----------------------------------------------------------------------------------------------------
# vf_coef 0.06175804755668379
# Max Train Score 16 Max Test Score 19
# Mean Train Score 1.8933156653777772 Mean Test Score 5.020861706041362
# ----------------------------------------------------------------------------------------------------
# vf_coef 0.06175804755668379
# Max Train Score 20 Max Test Score 21
# Mean Train Score 2.1301501631531474 Mean Test Score 5.114871759425762
# ----------------------------------------------------------------------------------------------------
# vf_coef 0.06175804755668379
# Max Train Score 19 Max Test Score 24
# Mean Train Score 2.0065510453908364 Mean Test Score 5.183760092913137
# ----------------------------------------------------------------------------------------------------
# vf_coef 0.06175804755668379
# Max Train Score 12 Max Test Score 18
# Mean Train Score 1.7355494844104504 Mean Test Score 3.4591632918109845
# ----------------------------------------------------------------------------------------------------
# vf_coef 0.06175804755668379
# Max Train Score 20 Max Test Score 17
# Mean Train Score 1.7103076439894578 Mean Test Score 4.624236828707763
# ----------------------------------------------------------------------------------------------------
# vf_coef 0.06175804755668379
# Max Train Score 25 Max Test Score 24
# Mean Train Score 2.6051716173568273 Mean Test Score 6.491214950036414
# ----------------------------------------------------------------------------------------------------
# vf_coef 0.06175804755668379
# Max Train Score 19 Max Test Score 19
# Mean Train Score 2.0496338599131585 Mean Test Score 4.418586281516004
# ----------------------------------------------------------------------------------------------------
# vf_coef 0.06175804755668379
# Max Train Score 11 Max Test Score 17
# Mean Train Score 1.7184363097385962 Mean Test Score 3.744687805370703
# ----------------------------------------------------------------------------------------------------
# vf_coef 0.06175804755668379
# Max Train Score 19 Max Test Score 17
# Mean Train Score 2.407289831241573 Mean Test Score 2.7306291641140263
# ----------------------------------------------------------------------------------------------------
# vf_coef 0.06175804755668379
# Max Train Score 33 Max Test Score 27
# Mean Train Score 3.014821778727757 Mean Test Score 6.201672080891841
# ----------------------------------------------------------------------------------------------------
# vf_coef 0.06175804755668379
# Max Train Score 18 Max Test Score 26
# Mean Train Score 1.9471147276775524 Mean Test Score 5.0649513279107
# ----------------------------------------------------------------------------------------------------
# vf_coef 0.06175804755668379
# Max Train Score 26 Max Test Score 24
# Mean Train Score 2.2894178592781 Mean Test Score 4.949487708799457
# ----------------------------------------------------------------------------------------------------
# vf_coef 0.06175804755668379
# Max Train Score 17 Max Test Score 19
# Mean Train Score 2.4712702610779225 Mean Test Score 4.247423973843965
# ----------------------------------------------------------------------------------------------------
# vf_coef 0.06175804755668379
# Max Train Score 18 Max Test Score 19
# Mean Train Score 2.2155663318745873 Mean Test Score 4.578873318119271
# ----------------------------------------------------------------------------------------------------
# vf_coef 0.06175804755668379
# Max Train Score 22 Max Test Score 27
# Mean Train Score 2.988766409785627 Mean Test Score 5.809063991471831
# ----------------------------------------------------------------------------------------------------
# vf_coef 0.06175804755668379
# Max Train Score 25 Max Test Score 32
# Mean Train Score 2.822373297443182 Mean Test Score 5.409008656768258
# ----------------------------------------------------------------------------------------------------
# vf_coef 0.06175804755668379
# Max Train Score 12 Max Test Score 9
# Mean Train Score 1.6473401022716516 Mean Test Score 2.202170715706884
# ----------------------------------------------------------------------------------------------------
# vf_coef 0.06175804755668379
# Max Train Score 29 Max Test Score 25
# Mean Train Score 2.7009325051417363 Mean Test Score 5.394278560537753
# ----------------------------------------------------------------------------------------------------
# vf_coef 0.06175804755668379
# Max Train Score 17 Max Test Score 26
# Mean Train Score 1.8831786471088945 Mean Test Score 4.962263336688877
# ----------------------------------------------------------------------------------------------------
# vf_coef 0.06175804755668379
# Max Train Score 15 Max Test Score 25
# Mean Train Score 1.790283413535672 Mean Test Score 4.974662830539852
# ----------------------------------------------------------------------------------------------------
# vf_coef 0.06175804755668379
# Max Train Score 11 Max Test Score 9
# Mean Train Score 1.513021408406091 Mean Test Score 2.03651891240694
# ----------------------------------------------------------------------------------------------------
# vf_coef 0.06175804755668379
# Max Train Score 19 Max Test Score 20
# Mean Train Score 2.1147012161128256 Mean Test Score 3.9686855093018636
# ----------------------------------------------------------------------------------------------------
# vf_coef 0.06175804755668379
# Max Train Score 20 Max Test Score 21
# Mean Train Score 2.2578662884981164 Mean Test Score 4.325378217363663
# ----------------------------------------------------------------------------------------------------

# %%
formatted_dict = {'vf_coef': [],
                  'metrics': [],
                  'results': []}

for vf_coef, result in results.items():
    _, max_train_score, max_test_score, mean_train_score, mean_test_score = result

    formatted_dict['vf_coef'].append(vf_coef)
    formatted_dict['metrics'].append('Max Train Score')
    formatted_dict['results'].append(max_train_score)

    formatted_dict['vf_coef'].append(vf_coef)
    formatted_dict['metrics'].append('Max Test Score')
    formatted_dict['results'].append(max_test_score)
    
    formatted_dict['vf_coef'].append(vf_coef)
    formatted_dict['metrics'].append('Mean Train Score')
    formatted_dict['results'].append(mean_train_score)

    formatted_dict['vf_coef'].append(vf_coef)
    formatted_dict['metrics'].append('Mean Test Score')
    formatted_dict['results'].append(mean_test_score)

df_metrics = pd.DataFrame(formatted_dict)
sns.lineplot(data=df_metrics, x='vf_coef', y='results', hue='metrics')
# Out:
# <AxesSubplot:xlabel='vf_coef', ylabel='results'>

# %% [markdown]
# **Descrição**
# O A2C é um algoritmo on-policy derivado do REINFORCE que introduz o conceito de *advantage value*. Assim, o algoritmo funciona do seguindo modo: o "Crítico" estima a função valor, enquanto o "Ator" atualiza a política na direção sugerida pelo Crítico. [https://towardsdatascience.com/understanding-actor-critic-methods-931b97b6df3f]
#
# **Discussão:**
#
# Podemos observar que a variação do fator de desconto gamma tem uma influência bastante significativa nos resultados obtidos pelo agente. Em contra partida, os parâmetros "coeficiente de entropia" e "coeficiente da Função Valor", ambos usados no cálculo da *loss*, não trouxeram nenhum ganho expressivo. A partir de uma análise exploratória do tipo *random search* sobre esses parâmetros, observamos que valores menores para o gamma geram resultados bastante ruins, enquanto que valores no intevalo \[0.95, 1.0\] geram os melhores resultados. Além disso, também observamos que quanto maiores os valores do "coeficiente de entropia" e do "coeficiente da Função Valor", piores são os resultados. Experimentamos normalizar o *advantage value*, pois é indicado como uma boa prática no artigo [1], porém os resultados foram piores que não normalizando. Acreditamos que esse resultado pior se deva ao fato de a função *reward* retornar -50 quando a cobra morre, 10 quando ela come a maçã e zero nos outros casos, dessa forma não uma variedade que seja grande o suficiente para que a normalização ajude de alguma forma. Por fim, a melhor configuração obtida foi com:
#
# gamma = 0.98
# coeficiente de entropia = 0.0 (default)
# coeficiente da Função Valor  = 0.5 (default)
#
# A pontuação máxima obtida  por esse algoritmo após o treino foi de 36.
#
# **Referências**
#
# [1] Mnih, Volodymyr, et al. "Asynchronous methods for deep reinforcement learning." International conference on machine learning. PMLR, 2016.
